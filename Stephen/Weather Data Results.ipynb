# %%
# Dependencies
import requests
import json
import pandas as pd
import numpy as np
import csv
import itertools

# API key
from config import api_key

with open(r'C:\Users\skm72\Desktop\Project Repo\Project-1\Stephen\Weather Json\Jan.json') as jan:
   jan_data = json.load(jan)
with open(r'C:\Users\skm72\Desktop\Project Repo\Project-1\Stephen\Weather Json\Feb.json') as feb:
   feb_data = json.load(feb)
with open(r'C:\Users\skm72\Desktop\Project Repo\Project-1\Stephen\Weather Json\Mar.json') as mar:
   mar_data = json.load(mar)
with open(r'C:\Users\skm72\Desktop\Project Repo\Project-1\Stephen\Weather Json\Apr.json') as apr:
   apr_data = json.load(apr)
with open(r'C:\Users\skm72\Desktop\Project Repo\Project-1\Stephen\Weather Json\May.json') as may:
   may_data = json.load(may)
with open(r'C:\Users\skm72\Desktop\Project Repo\Project-1\Stephen\Weather Json\Jun.json') as jun:
   jun_data = json.load(jun)
with open(r'C:\Users\skm72\Desktop\Project Repo\Project-1\Stephen\Weather Json\Jul.json') as jul:
   jul_data = json.load(jul)
with open(r'C:\Users\skm72\Desktop\Project Repo\Project-1\Stephen\Weather Json\Aug.json') as aug:
   aug_data = json.load(aug)
with open(r'C:\Users\skm72\Desktop\Project Repo\Project-1\Stephen\Weather Json\Sep.json') as sep:
   sep_data = json.load(sep)
with open(r'C:\Users\skm72\Desktop\Project Repo\Project-1\Stephen\Weather Json\Oct.json') as oct:
   oct_data = json.load(oct)
with open(r'C:\Users\skm72\Desktop\Project Repo\Project-1\Stephen\Weather Json\Nov.json') as nov:
   nov_data = json.load(nov)
with open(r'C:\Users\skm72\Desktop\Project Repo\Project-1\Stephen\Weather Json\Dec.json') as dec:
   dec_data = json.load(dec)

# %%
weather_df = {}
weather_df = pd.DataFrame(weather_df)
weather_df["January"] = ""
weather_df["February"] = ""
weather_df["March"] = ""
weather_df["April"] = ""
weather_df["May"] = ""
weather_df["June"] = ""
weather_df["July"] = ""
weather_df["August"] = ""
weather_df["September"] = ""
weather_df["October"] = ""
weather_df["November"] = ""
weather_df["December"] = ""

# %%
# results for January and each of the top 50 states
x = np.arange(0, 31, 1)
results0 = []
results1 = []
results2 = []
results3 = []
results4 = []
results5 = []
results6 = []
results7 = []
results8 = []
results9 = []
results10 = []
results11 = []
results12 = []
results13 = []
results14 = []
results15 = []
results16 = []
results17 = []
results18 = []
results19 = []
results20 = []
results21 = []
results22 = []
results23 = []
results24 = []
results25 = []
results26 = []
results27 = []
results28 = []
results29 = []
results30 = []
results31 = []
results32 = []
results33 = []
results34 = []
results35 = []
results36 = []
results37 = []
results38 = []
results39 = []
results40 = []
results41 = []
results42 = []
results43 = []
results44 = []
results45 = []
results46 = []
results47 = []
results48 = []
results49 = []

# Pulling all the average temps per day from each city
for x in x:
        results0.append(jan_data[0]["data"]["weather"][x]["avgtempF"])
        results1.append(jan_data[1]["data"]["weather"][x]["avgtempF"])
        results2.append(jan_data[2]["data"]["weather"][x]["avgtempF"])
        results3.append(jan_data[3]["data"]["weather"][x]["avgtempF"])
        results4.append(jan_data[4]["data"]["weather"][x]["avgtempF"])
        results5.append(jan_data[5]["data"]["weather"][x]["avgtempF"])
        results6.append(jan_data[6]["data"]["weather"][x]["avgtempF"])
        results7.append(jan_data[7]["data"]["weather"][x]["avgtempF"])
        results8.append(jan_data[8]["data"]["weather"][x]["avgtempF"])
        results9.append(jan_data[9]["data"]["weather"][x]["avgtempF"])
        results10.append(jan_data[10]["data"]["weather"][x]["avgtempF"])
        results11.append(jan_data[11]["data"]["weather"][x]["avgtempF"])
        results12.append(jan_data[12]["data"]["weather"][x]["avgtempF"])
        results13.append(jan_data[13]["data"]["weather"][x]["avgtempF"])
        results14.append(jan_data[14]["data"]["weather"][x]["avgtempF"])
        results15.append(jan_data[15]["data"]["weather"][x]["avgtempF"])
        results16.append(jan_data[16]["data"]["weather"][x]["avgtempF"])
        results17.append(jan_data[17]["data"]["weather"][x]["avgtempF"])
        results18.append(jan_data[18]["data"]["weather"][x]["avgtempF"])
        results19.append(jan_data[19]["data"]["weather"][x]["avgtempF"])
        results20.append(jan_data[20]["data"]["weather"][x]["avgtempF"])
        results21.append(jan_data[21]["data"]["weather"][x]["avgtempF"])
        results22.append(jan_data[22]["data"]["weather"][x]["avgtempF"])
        results23.append(jan_data[23]["data"]["weather"][x]["avgtempF"])
        results24.append(jan_data[24]["data"]["weather"][x]["avgtempF"])
        results25.append(jan_data[25]["data"]["weather"][x]["avgtempF"])
        results26.append(jan_data[26]["data"]["weather"][x]["avgtempF"])
        results27.append(jan_data[27]["data"]["weather"][x]["avgtempF"])
        results28.append(jan_data[28]["data"]["weather"][x]["avgtempF"])
        results29.append(jan_data[29]["data"]["weather"][x]["avgtempF"])
        results30.append(jan_data[30]["data"]["weather"][x]["avgtempF"])
        results31.append(jan_data[31]["data"]["weather"][x]["avgtempF"])
        results32.append(jan_data[32]["data"]["weather"][x]["avgtempF"])
        results33.append(jan_data[33]["data"]["weather"][x]["avgtempF"])
        results34.append(jan_data[34]["data"]["weather"][x]["avgtempF"])
        results35.append(jan_data[35]["data"]["weather"][x]["avgtempF"])
        results36.append(jan_data[36]["data"]["weather"][x]["avgtempF"])
        results37.append(jan_data[37]["data"]["weather"][x]["avgtempF"])
        results38.append(jan_data[38]["data"]["weather"][x]["avgtempF"])
        results39.append(jan_data[39]["data"]["weather"][x]["avgtempF"])
        results40.append(jan_data[40]["data"]["weather"][x]["avgtempF"])
        results41.append(jan_data[41]["data"]["weather"][x]["avgtempF"])
        results42.append(jan_data[42]["data"]["weather"][x]["avgtempF"])
        results43.append(jan_data[43]["data"]["weather"][x]["avgtempF"])
        results44.append(jan_data[44]["data"]["weather"][x]["avgtempF"])
        results45.append(jan_data[45]["data"]["weather"][x]["avgtempF"])
        results46.append(jan_data[46]["data"]["weather"][x]["avgtempF"])
        results47.append(jan_data[47]["data"]["weather"][x]["avgtempF"])
        results48.append(jan_data[48]["data"]["weather"][x]["avgtempF"])
        results49.append(jan_data[49]["data"]["weather"][x]["avgtempF"])

# %%
# Putting all the data into the df
weather_df.loc["New York","January"] = results0
weather_df.loc["Los Angeles","January"] = results1
weather_df.loc["Chicago","January"] = results2
weather_df.loc["Houston","January"] = results3
weather_df.loc["Phoenix","January"] = results4
weather_df.loc["Philadelphia","January"] = results5
weather_df.loc["San Antonio","January"] = results6
weather_df.loc["San Diego","January"] = results7
weather_df.loc["Dallas","January"] = results8
weather_df.loc["San Jose","January"] = results9

weather_df.loc["Austin","January"] = results10
weather_df.loc["Jacksonville","January"] = results11
weather_df.loc["Fort Worth","January"] = results12
weather_df.loc["Columbus","January"] = results13
weather_df.loc["Charlotte","January"] = results14
weather_df.loc["San Francisco","January"] = results15
weather_df.loc["Indianapolis","January"] = results16
weather_df.loc["Seattle","January"] = results17
weather_df.loc["Denver","January"] = results18
weather_df.loc["Washington","January"] = results19

weather_df.loc["Boston","January"] = results20
weather_df.loc["El Paso","January"] = results21
weather_df.loc["Nashville","January"] = results22
weather_df.loc["Detroit","January"] = results23
weather_df.loc["Oklahoma City","January"] = results24
weather_df.loc["Portland","January"] = results25
weather_df.loc["Las Vegas","January"] = results26
weather_df.loc["Memphis","January"] = results27
weather_df.loc["Louisville","January"] = results28
weather_df.loc["Baltimore","January"] = results29

weather_df.loc["Milwaukee","January"] = results30
weather_df.loc["Albuquerque","January"] = results31
weather_df.loc["Tucson","January"] = results32
weather_df.loc["Fresno","January"] = results33
weather_df.loc["Mesa","January"] = results34
weather_df.loc["Sacramento","January"] = results35
weather_df.loc["Atlanta","January"] = results36
weather_df.loc["Kansas City","January"] = results37
weather_df.loc["Colorado Springs","January"] = results38
weather_df.loc["Omaha","January"] = results39

weather_df.loc["Raleigh","January"] = results40
weather_df.loc["Miami","January"] = results41
weather_df.loc["Long Beach","January"] = results42
weather_df.loc["Virginia Beach","January"] = results43
weather_df.loc["Oakland","January"] = results44
weather_df.loc["Minneapolis","January"] = results45
weather_df.loc["Tulsa","January"] = results46
weather_df.loc["Tampa","January"] = results47
weather_df.loc["Arlington","January"] = results48
weather_df.loc["New Orleans","January"] = results49

# %%
# results for February and each of the top 50 states
x = np.arange(0, 28, 1)
results0 = []
results1 = []
results2 = []
results3 = []
results4 = []
results5 = []
results6 = []
results7 = []
results8 = []
results9 = []
results10 = []
results11 = []
results12 = []
results13 = []
results14 = []
results15 = []
results16 = []
results17 = []
results18 = []
results19 = []
results20 = []
results21 = []
results22 = []
results23 = []
results24 = []
results25 = []
results26 = []
results27 = []
results28 = []
results29 = []
results30 = []
results31 = []
results32 = []
results33 = []
results34 = []
results35 = []
results36 = []
results37 = []
results38 = []
results39 = []
results40 = []
results41 = []
results42 = []
results43 = []
results44 = []
results45 = []
results46 = []
results47 = []
results48 = []
results49 = []

# Pulling all the average temps per day from each city
for x in x:
        results0.append(feb_data[0]["data"]["weather"][x]["avgtempF"])
        results1.append(feb_data[1]["data"]["weather"][x]["avgtempF"])
        results2.append(feb_data[2]["data"]["weather"][x]["avgtempF"])
        results3.append(feb_data[3]["data"]["weather"][x]["avgtempF"])
        results4.append(feb_data[4]["data"]["weather"][x]["avgtempF"])
        results5.append(feb_data[5]["data"]["weather"][x]["avgtempF"])
        results6.append(feb_data[6]["data"]["weather"][x]["avgtempF"])
        results7.append(feb_data[7]["data"]["weather"][x]["avgtempF"])
        results8.append(feb_data[8]["data"]["weather"][x]["avgtempF"])
        results9.append(feb_data[9]["data"]["weather"][x]["avgtempF"])
        results10.append(feb_data[10]["data"]["weather"][x]["avgtempF"])
        results11.append(feb_data[11]["data"]["weather"][x]["avgtempF"])
        results12.append(feb_data[12]["data"]["weather"][x]["avgtempF"])
        results13.append(feb_data[13]["data"]["weather"][x]["avgtempF"])
        results14.append(feb_data[14]["data"]["weather"][x]["avgtempF"])
        results15.append(feb_data[15]["data"]["weather"][x]["avgtempF"])
        results16.append(feb_data[16]["data"]["weather"][x]["avgtempF"])
        results17.append(feb_data[17]["data"]["weather"][x]["avgtempF"])
        results18.append(feb_data[18]["data"]["weather"][x]["avgtempF"])
        results19.append(feb_data[19]["data"]["weather"][x]["avgtempF"])
        results20.append(feb_data[20]["data"]["weather"][x]["avgtempF"])
        results21.append(feb_data[21]["data"]["weather"][x]["avgtempF"])
        results22.append(feb_data[22]["data"]["weather"][x]["avgtempF"])
        results23.append(feb_data[23]["data"]["weather"][x]["avgtempF"])
        results24.append(feb_data[24]["data"]["weather"][x]["avgtempF"])
        results25.append(feb_data[25]["data"]["weather"][x]["avgtempF"])
        results26.append(feb_data[26]["data"]["weather"][x]["avgtempF"])
        results27.append(feb_data[27]["data"]["weather"][x]["avgtempF"])
        results28.append(feb_data[28]["data"]["weather"][x]["avgtempF"])
        results29.append(feb_data[29]["data"]["weather"][x]["avgtempF"])
        results30.append(feb_data[30]["data"]["weather"][x]["avgtempF"])
        results31.append(feb_data[31]["data"]["weather"][x]["avgtempF"])
        results32.append(feb_data[32]["data"]["weather"][x]["avgtempF"])
        results33.append(feb_data[33]["data"]["weather"][x]["avgtempF"])
        results34.append(feb_data[34]["data"]["weather"][x]["avgtempF"])
        results35.append(feb_data[35]["data"]["weather"][x]["avgtempF"])
        results36.append(feb_data[36]["data"]["weather"][x]["avgtempF"])
        results37.append(feb_data[37]["data"]["weather"][x]["avgtempF"])
        results38.append(feb_data[38]["data"]["weather"][x]["avgtempF"])
        results39.append(feb_data[39]["data"]["weather"][x]["avgtempF"])
        results40.append(feb_data[40]["data"]["weather"][x]["avgtempF"])
        results41.append(feb_data[41]["data"]["weather"][x]["avgtempF"])
        results42.append(feb_data[42]["data"]["weather"][x]["avgtempF"])
        results43.append(feb_data[43]["data"]["weather"][x]["avgtempF"])
        results44.append(feb_data[44]["data"]["weather"][x]["avgtempF"])
        results45.append(feb_data[45]["data"]["weather"][x]["avgtempF"])
        results46.append(feb_data[46]["data"]["weather"][x]["avgtempF"])
        results47.append(feb_data[47]["data"]["weather"][x]["avgtempF"])
        results48.append(feb_data[48]["data"]["weather"][x]["avgtempF"])
        results49.append(feb_data[49]["data"]["weather"][x]["avgtempF"])

# %%
# Putting all the data into the df
weather_df.loc["New York","February"] = results0
weather_df.loc["Los Angeles","February"] = results1
weather_df.loc["Chicago","February"] = results2
weather_df.loc["Houston","February"] = results3
weather_df.loc["Phoenix","February"] = results4
weather_df.loc["Philadelphia","February"] = results5
weather_df.loc["San Antonio","February"] = results6
weather_df.loc["San Diego","February"] = results7
weather_df.loc["Dallas","February"] = results8
weather_df.loc["San Jose","February"] = results9

weather_df.loc["Austin","February"] = results10
weather_df.loc["Jacksonville","February"] = results11
weather_df.loc["Fort Worth","February"] = results12
weather_df.loc["Columbus","February"] = results13
weather_df.loc["Charlotte","February"] = results14
weather_df.loc["San Francisco","February"] = results15
weather_df.loc["Indianapolis","February"] = results16
weather_df.loc["Seattle","February"] = results17
weather_df.loc["Denver","February"] = results18
weather_df.loc["Washington","February"] = results19

weather_df.loc["Boston","February"] = results20
weather_df.loc["El Paso","February"] = results21
weather_df.loc["Nashville","February"] = results22
weather_df.loc["Detroit","February"] = results23
weather_df.loc["Oklahoma City","February"] = results24
weather_df.loc["Portland","February"] = results25
weather_df.loc["Las Vegas","February"] = results26
weather_df.loc["Memphis","February"] = results27
weather_df.loc["Louisville","February"] = results28
weather_df.loc["Baltimore","February"] = results29

weather_df.loc["Milwaukee","February"] = results30
weather_df.loc["Albuquerque","February"] = results31
weather_df.loc["Tucson","February"] = results32
weather_df.loc["Fresno","February"] = results33
weather_df.loc["Mesa","February"] = results34
weather_df.loc["Sacramento","February"] = results35
weather_df.loc["Atlanta","February"] = results36
weather_df.loc["Kansas City","February"] = results37
weather_df.loc["Colorado Springs","February"] = results38
weather_df.loc["Omaha","February"] = results39

weather_df.loc["Raleigh","February"] = results40
weather_df.loc["Miami","February"] = results41
weather_df.loc["Long Beach","February"] = results42
weather_df.loc["Virginia Beach","February"] = results43
weather_df.loc["Oakland","February"] = results44
weather_df.loc["Minneapolis","February"] = results45
weather_df.loc["Tulsa","February"] = results46
weather_df.loc["Tampa","February"] = results47
weather_df.loc["Arlington","February"] = results48
weather_df.loc["New Orleans","February"] = results49

# %%
# results for March and each of the top 50 states
x = np.arange(0, 31, 1)
results0 = []
results1 = []
results2 = []
results3 = []
results4 = []
results5 = []
results6 = []
results7 = []
results8 = []
results9 = []
results10 = []
results11 = []
results12 = []
results13 = []
results14 = []
results15 = []
results16 = []
results17 = []
results18 = []
results19 = []
results20 = []
results21 = []
results22 = []
results23 = []
results24 = []
results25 = []
results26 = []
results27 = []
results28 = []
results29 = []
results30 = []
results31 = []
results32 = []
results33 = []
results34 = []
results35 = []
results36 = []
results37 = []
results38 = []
results39 = []
results40 = []
results41 = []
results42 = []
results43 = []
results44 = []
results45 = []
results46 = []
results47 = []
results48 = []
results49 = []

# Pulling all the average temps per day from each city
for x in x:
        results0.append(mar_data[0]["data"]["weather"][x]["avgtempF"])
        results1.append(mar_data[1]["data"]["weather"][x]["avgtempF"])
        results2.append(mar_data[2]["data"]["weather"][x]["avgtempF"])
        results3.append(mar_data[3]["data"]["weather"][x]["avgtempF"])
        results4.append(mar_data[4]["data"]["weather"][x]["avgtempF"])
        results5.append(mar_data[5]["data"]["weather"][x]["avgtempF"])
        results6.append(mar_data[6]["data"]["weather"][x]["avgtempF"])
        results7.append(mar_data[7]["data"]["weather"][x]["avgtempF"])
        results8.append(mar_data[8]["data"]["weather"][x]["avgtempF"])
        results9.append(mar_data[9]["data"]["weather"][x]["avgtempF"])
        results10.append(mar_data[10]["data"]["weather"][x]["avgtempF"])
        results11.append(mar_data[11]["data"]["weather"][x]["avgtempF"])
        results12.append(mar_data[12]["data"]["weather"][x]["avgtempF"])
        results13.append(mar_data[13]["data"]["weather"][x]["avgtempF"])
        results14.append(mar_data[14]["data"]["weather"][x]["avgtempF"])
        results15.append(mar_data[15]["data"]["weather"][x]["avgtempF"])
        results16.append(mar_data[16]["data"]["weather"][x]["avgtempF"])
        results17.append(mar_data[17]["data"]["weather"][x]["avgtempF"])
        results18.append(mar_data[18]["data"]["weather"][x]["avgtempF"])
        results19.append(mar_data[19]["data"]["weather"][x]["avgtempF"])
        results20.append(mar_data[20]["data"]["weather"][x]["avgtempF"])
        results21.append(mar_data[21]["data"]["weather"][x]["avgtempF"])
        results22.append(mar_data[22]["data"]["weather"][x]["avgtempF"])
        results23.append(mar_data[23]["data"]["weather"][x]["avgtempF"])
        results24.append(mar_data[24]["data"]["weather"][x]["avgtempF"])
        results25.append(mar_data[25]["data"]["weather"][x]["avgtempF"])
        results26.append(mar_data[26]["data"]["weather"][x]["avgtempF"])
        results27.append(mar_data[27]["data"]["weather"][x]["avgtempF"])
        results28.append(mar_data[28]["data"]["weather"][x]["avgtempF"])
        results29.append(mar_data[29]["data"]["weather"][x]["avgtempF"])
        results30.append(mar_data[30]["data"]["weather"][x]["avgtempF"])
        results31.append(mar_data[31]["data"]["weather"][x]["avgtempF"])
        results32.append(mar_data[32]["data"]["weather"][x]["avgtempF"])
        results33.append(mar_data[33]["data"]["weather"][x]["avgtempF"])
        results34.append(mar_data[34]["data"]["weather"][x]["avgtempF"])
        results35.append(mar_data[35]["data"]["weather"][x]["avgtempF"])
        results36.append(mar_data[36]["data"]["weather"][x]["avgtempF"])
        results37.append(mar_data[37]["data"]["weather"][x]["avgtempF"])
        results38.append(mar_data[38]["data"]["weather"][x]["avgtempF"])
        results39.append(mar_data[39]["data"]["weather"][x]["avgtempF"])
        results40.append(mar_data[40]["data"]["weather"][x]["avgtempF"])
        results41.append(mar_data[41]["data"]["weather"][x]["avgtempF"])
        results42.append(mar_data[42]["data"]["weather"][x]["avgtempF"])
        results43.append(mar_data[43]["data"]["weather"][x]["avgtempF"])
        results44.append(mar_data[44]["data"]["weather"][x]["avgtempF"])
        results45.append(mar_data[45]["data"]["weather"][x]["avgtempF"])
        results46.append(mar_data[46]["data"]["weather"][x]["avgtempF"])
        results47.append(mar_data[47]["data"]["weather"][x]["avgtempF"])
        results48.append(mar_data[48]["data"]["weather"][x]["avgtempF"])
        results49.append(mar_data[49]["data"]["weather"][x]["avgtempF"])

# %%
# Putting all the data into the df
weather_df.loc["New York","March"] = results0
weather_df.loc["Los Angeles","March"] = results1
weather_df.loc["Chicago","March"] = results2
weather_df.loc["Houston","March"] = results3
weather_df.loc["Phoenix","March"] = results4
weather_df.loc["Philadelphia","March"] = results5
weather_df.loc["San Antonio","March"] = results6
weather_df.loc["San Diego","March"] = results7
weather_df.loc["Dallas","March"] = results8
weather_df.loc["San Jose","March"] = results9

weather_df.loc["Austin","March"] = results10
weather_df.loc["Jacksonville","March"] = results11
weather_df.loc["Fort Worth","March"] = results12
weather_df.loc["Columbus","March"] = results13
weather_df.loc["Charlotte","March"] = results14
weather_df.loc["San Francisco","March"] = results15
weather_df.loc["Indianapolis","March"] = results16
weather_df.loc["Seattle","March"] = results17
weather_df.loc["Denver","March"] = results18
weather_df.loc["Washington","March"] = results19

weather_df.loc["Boston","March"] = results20
weather_df.loc["El Paso","March"] = results21
weather_df.loc["Nashville","March"] = results22
weather_df.loc["Detroit","March"] = results23
weather_df.loc["Oklahoma City","March"] = results24
weather_df.loc["Portland","March"] = results25
weather_df.loc["Las Vegas","March"] = results26
weather_df.loc["Memphis","March"] = results27
weather_df.loc["Louisville","March"] = results28
weather_df.loc["Baltimore","March"] = results29

weather_df.loc["Milwaukee","March"] = results30
weather_df.loc["Albuquerque","March"] = results31
weather_df.loc["Tucson","March"] = results32
weather_df.loc["Fresno","March"] = results33
weather_df.loc["Mesa","March"] = results34
weather_df.loc["Sacramento","March"] = results35
weather_df.loc["Atlanta","March"] = results36
weather_df.loc["Kansas City","March"] = results37
weather_df.loc["Colorado Springs","March"] = results38
weather_df.loc["Omaha","March"] = results39

weather_df.loc["Raleigh","March"] = results40
weather_df.loc["Miami","March"] = results41
weather_df.loc["Long Beach","March"] = results42
weather_df.loc["Virginia Beach","March"] = results43
weather_df.loc["Oakland","March"] = results44
weather_df.loc["Minneapolis","March"] = results45
weather_df.loc["Tulsa","March"] = results46
weather_df.loc["Tampa","March"] = results47
weather_df.loc["Arlington","March"] = results48
weather_df.loc["New Orleans","March"] = results49

# %%
# results for April and each of the top 50 states
x = np.arange(0, 30, 1)
results0 = []
results1 = []
results2 = []
results3 = []
results4 = []
results5 = []
results6 = []
results7 = []
results8 = []
results9 = []
results10 = []
results11 = []
results12 = []
results13 = []
results14 = []
results15 = []
results16 = []
results17 = []
results18 = []
results19 = []
results20 = []
results21 = []
results22 = []
results23 = []
results24 = []
results25 = []
results26 = []
results27 = []
results28 = []
results29 = []
results30 = []
results31 = []
results32 = []
results33 = []
results34 = []
results35 = []
results36 = []
results37 = []
results38 = []
results39 = []
results40 = []
results41 = []
results42 = []
results43 = []
results44 = []
results45 = []
results46 = []
results47 = []
results48 = []
results49 = []

# Pulling all the average temps per day from each city
for x in x:
        results0.append(apr_data[0]["data"]["weather"][x]["avgtempF"])
        results1.append(apr_data[1]["data"]["weather"][x]["avgtempF"])
        results2.append(apr_data[2]["data"]["weather"][x]["avgtempF"])
        results3.append(apr_data[3]["data"]["weather"][x]["avgtempF"])
        results4.append(apr_data[4]["data"]["weather"][x]["avgtempF"])
        results5.append(apr_data[5]["data"]["weather"][x]["avgtempF"])
        results6.append(apr_data[6]["data"]["weather"][x]["avgtempF"])
        results7.append(apr_data[7]["data"]["weather"][x]["avgtempF"])
        results8.append(apr_data[8]["data"]["weather"][x]["avgtempF"])
        results9.append(apr_data[9]["data"]["weather"][x]["avgtempF"])
        results10.append(apr_data[10]["data"]["weather"][x]["avgtempF"])
        results11.append(apr_data[11]["data"]["weather"][x]["avgtempF"])
        results12.append(apr_data[12]["data"]["weather"][x]["avgtempF"])
        results13.append(apr_data[13]["data"]["weather"][x]["avgtempF"])
        results14.append(apr_data[14]["data"]["weather"][x]["avgtempF"])
        results15.append(apr_data[15]["data"]["weather"][x]["avgtempF"])
        results16.append(apr_data[16]["data"]["weather"][x]["avgtempF"])
        results17.append(apr_data[17]["data"]["weather"][x]["avgtempF"])
        results18.append(apr_data[18]["data"]["weather"][x]["avgtempF"])
        results19.append(apr_data[19]["data"]["weather"][x]["avgtempF"])
        results20.append(apr_data[20]["data"]["weather"][x]["avgtempF"])
        results21.append(apr_data[21]["data"]["weather"][x]["avgtempF"])
        results22.append(apr_data[22]["data"]["weather"][x]["avgtempF"])
        results23.append(apr_data[23]["data"]["weather"][x]["avgtempF"])
        results24.append(apr_data[24]["data"]["weather"][x]["avgtempF"])
        results25.append(apr_data[25]["data"]["weather"][x]["avgtempF"])
        results26.append(apr_data[26]["data"]["weather"][x]["avgtempF"])
        results27.append(apr_data[27]["data"]["weather"][x]["avgtempF"])
        results28.append(apr_data[28]["data"]["weather"][x]["avgtempF"])
        results29.append(apr_data[29]["data"]["weather"][x]["avgtempF"])
        results30.append(apr_data[30]["data"]["weather"][x]["avgtempF"])
        results31.append(apr_data[31]["data"]["weather"][x]["avgtempF"])
        results32.append(apr_data[32]["data"]["weather"][x]["avgtempF"])
        results33.append(apr_data[33]["data"]["weather"][x]["avgtempF"])
        results34.append(apr_data[34]["data"]["weather"][x]["avgtempF"])
        results35.append(apr_data[35]["data"]["weather"][x]["avgtempF"])
        results36.append(apr_data[36]["data"]["weather"][x]["avgtempF"])
        results37.append(apr_data[37]["data"]["weather"][x]["avgtempF"])
        results38.append(apr_data[38]["data"]["weather"][x]["avgtempF"])
        results39.append(apr_data[39]["data"]["weather"][x]["avgtempF"])
        results40.append(apr_data[40]["data"]["weather"][x]["avgtempF"])
        results41.append(apr_data[41]["data"]["weather"][x]["avgtempF"])
        results42.append(apr_data[42]["data"]["weather"][x]["avgtempF"])
        results43.append(apr_data[43]["data"]["weather"][x]["avgtempF"])
        results44.append(apr_data[44]["data"]["weather"][x]["avgtempF"])
        results45.append(apr_data[45]["data"]["weather"][x]["avgtempF"])
        results46.append(apr_data[46]["data"]["weather"][x]["avgtempF"])
        results47.append(apr_data[47]["data"]["weather"][x]["avgtempF"])
        results48.append(apr_data[48]["data"]["weather"][x]["avgtempF"])
        results49.append(apr_data[49]["data"]["weather"][x]["avgtempF"])

# %%
# Putting all the data into the df
weather_df.loc["New York","April"] = results0
weather_df.loc["Los Angeles","April"] = results1
weather_df.loc["Chicago","April"] = results2
weather_df.loc["Houston","April"] = results3
weather_df.loc["Phoenix","April"] = results4
weather_df.loc["Philadelphia","April"] = results5
weather_df.loc["San Antonio","April"] = results6
weather_df.loc["San Diego","April"] = results7
weather_df.loc["Dallas","April"] = results8
weather_df.loc["San Jose","April"] = results9

weather_df.loc["Austin","April"] = results10
weather_df.loc["Jacksonville","April"] = results11
weather_df.loc["Fort Worth","April"] = results12
weather_df.loc["Columbus","April"] = results13
weather_df.loc["Charlotte","April"] = results14
weather_df.loc["San Francisco","April"] = results15
weather_df.loc["Indianapolis","April"] = results16
weather_df.loc["Seattle","April"] = results17
weather_df.loc["Denver","April"] = results18
weather_df.loc["Washington","April"] = results19

weather_df.loc["Boston","April"] = results20
weather_df.loc["El Paso","April"] = results21
weather_df.loc["Nashville","April"] = results22
weather_df.loc["Detroit","April"] = results23
weather_df.loc["Oklahoma City","April"] = results24
weather_df.loc["Portland","April"] = results25
weather_df.loc["Las Vegas","April"] = results26
weather_df.loc["Memphis","April"] = results27
weather_df.loc["Louisville","April"] = results28
weather_df.loc["Baltimore","April"] = results29

weather_df.loc["Milwaukee","April"] = results30
weather_df.loc["Albuquerque","April"] = results31
weather_df.loc["Tucson","April"] = results32
weather_df.loc["Fresno","April"] = results33
weather_df.loc["Mesa","April"] = results34
weather_df.loc["Sacramento","April"] = results35
weather_df.loc["Atlanta","April"] = results36
weather_df.loc["Kansas City","April"] = results37
weather_df.loc["Colorado Springs","April"] = results38
weather_df.loc["Omaha","April"] = results39

weather_df.loc["Raleigh","April"] = results40
weather_df.loc["Miami","April"] = results41
weather_df.loc["Long Beach","April"] = results42
weather_df.loc["Virginia Beach","April"] = results43
weather_df.loc["Oakland","April"] = results44
weather_df.loc["Minneapolis","April"] = results45
weather_df.loc["Tulsa","April"] = results46
weather_df.loc["Tampa","April"] = results47
weather_df.loc["Arlington","April"] = results48
weather_df.loc["New Orleans","April"] = results49

# %%
# results for May and each of the top 50 states
x = np.arange(0, 31, 1)
results0 = []
results1 = []
results2 = []
results3 = []
results4 = []
results5 = []
results6 = []
results7 = []
results8 = []
results9 = []
results10 = []
results11 = []
results12 = []
results13 = []
results14 = []
results15 = []
results16 = []
results17 = []
results18 = []
results19 = []
results20 = []
results21 = []
results22 = []
results23 = []
results24 = []
results25 = []
results26 = []
results27 = []
results28 = []
results29 = []
results30 = []
results31 = []
results32 = []
results33 = []
results34 = []
results35 = []
results36 = []
results37 = []
results38 = []
results39 = []
results40 = []
results41 = []
results42 = []
results43 = []
results44 = []
results45 = []
results46 = []
results47 = []
results48 = []
results49 = []

# Pulling all the average temps per day from each city
for x in x:
        results0.append(may_data[0]["data"]["weather"][x]["avgtempF"])
        results1.append(may_data[1]["data"]["weather"][x]["avgtempF"])
        results2.append(may_data[2]["data"]["weather"][x]["avgtempF"])
        results3.append(may_data[3]["data"]["weather"][x]["avgtempF"])
        results4.append(may_data[4]["data"]["weather"][x]["avgtempF"])
        results5.append(may_data[5]["data"]["weather"][x]["avgtempF"])
        results6.append(may_data[6]["data"]["weather"][x]["avgtempF"])
        results7.append(may_data[7]["data"]["weather"][x]["avgtempF"])
        results8.append(may_data[8]["data"]["weather"][x]["avgtempF"])
        results9.append(may_data[9]["data"]["weather"][x]["avgtempF"])
        results10.append(may_data[10]["data"]["weather"][x]["avgtempF"])
        results11.append(may_data[11]["data"]["weather"][x]["avgtempF"])
        results12.append(may_data[12]["data"]["weather"][x]["avgtempF"])
        results13.append(may_data[13]["data"]["weather"][x]["avgtempF"])
        results14.append(may_data[14]["data"]["weather"][x]["avgtempF"])
        results15.append(may_data[15]["data"]["weather"][x]["avgtempF"])
        results16.append(may_data[16]["data"]["weather"][x]["avgtempF"])
        results17.append(may_data[17]["data"]["weather"][x]["avgtempF"])
        results18.append(may_data[18]["data"]["weather"][x]["avgtempF"])
        results19.append(may_data[19]["data"]["weather"][x]["avgtempF"])
        results20.append(may_data[20]["data"]["weather"][x]["avgtempF"])
        results21.append(may_data[21]["data"]["weather"][x]["avgtempF"])
        results22.append(may_data[22]["data"]["weather"][x]["avgtempF"])
        results23.append(may_data[23]["data"]["weather"][x]["avgtempF"])
        results24.append(may_data[24]["data"]["weather"][x]["avgtempF"])
        results25.append(may_data[25]["data"]["weather"][x]["avgtempF"])
        results26.append(may_data[26]["data"]["weather"][x]["avgtempF"])
        results27.append(may_data[27]["data"]["weather"][x]["avgtempF"])
        results28.append(may_data[28]["data"]["weather"][x]["avgtempF"])
        results29.append(may_data[29]["data"]["weather"][x]["avgtempF"])
        results30.append(may_data[30]["data"]["weather"][x]["avgtempF"])
        results31.append(may_data[31]["data"]["weather"][x]["avgtempF"])
        results32.append(may_data[32]["data"]["weather"][x]["avgtempF"])
        results33.append(may_data[33]["data"]["weather"][x]["avgtempF"])
        results34.append(may_data[34]["data"]["weather"][x]["avgtempF"])
        results35.append(may_data[35]["data"]["weather"][x]["avgtempF"])
        results36.append(may_data[36]["data"]["weather"][x]["avgtempF"])
        results37.append(may_data[37]["data"]["weather"][x]["avgtempF"])
        results38.append(may_data[38]["data"]["weather"][x]["avgtempF"])
        results39.append(may_data[39]["data"]["weather"][x]["avgtempF"])
        results40.append(may_data[40]["data"]["weather"][x]["avgtempF"])
        results41.append(may_data[41]["data"]["weather"][x]["avgtempF"])
        results42.append(may_data[42]["data"]["weather"][x]["avgtempF"])
        results43.append(may_data[43]["data"]["weather"][x]["avgtempF"])
        results44.append(may_data[44]["data"]["weather"][x]["avgtempF"])
        results45.append(may_data[45]["data"]["weather"][x]["avgtempF"])
        results46.append(may_data[46]["data"]["weather"][x]["avgtempF"])
        results47.append(may_data[47]["data"]["weather"][x]["avgtempF"])
        results48.append(may_data[48]["data"]["weather"][x]["avgtempF"])
        results49.append(may_data[49]["data"]["weather"][x]["avgtempF"])

# %%
# Putting all the data into the df
weather_df.loc["New York","May"] = results0
weather_df.loc["Los Angeles","May"] = results1
weather_df.loc["Chicago","May"] = results2
weather_df.loc["Houston","May"] = results3
weather_df.loc["Phoenix","May"] = results4
weather_df.loc["Philadelphia","May"] = results5
weather_df.loc["San Antonio","May"] = results6
weather_df.loc["San Diego","May"] = results7
weather_df.loc["Dallas","May"] = results8
weather_df.loc["San Jose","May"] = results9

weather_df.loc["Austin","May"] = results10
weather_df.loc["Jacksonville","May"] = results11
weather_df.loc["Fort Worth","May"] = results12
weather_df.loc["Columbus","May"] = results13
weather_df.loc["Charlotte","May"] = results14
weather_df.loc["San Francisco","May"] = results15
weather_df.loc["Indianapolis","May"] = results16
weather_df.loc["Seattle","May"] = results17
weather_df.loc["Denver","May"] = results18
weather_df.loc["Washington","May"] = results19

weather_df.loc["Boston","May"] = results20
weather_df.loc["El Paso","May"] = results21
weather_df.loc["Nashville","May"] = results22
weather_df.loc["Detroit","May"] = results23
weather_df.loc["Oklahoma City","May"] = results24
weather_df.loc["Portland","May"] = results25
weather_df.loc["Las Vegas","May"] = results26
weather_df.loc["Memphis","May"] = results27
weather_df.loc["Louisville","May"] = results28
weather_df.loc["Baltimore","May"] = results29

weather_df.loc["Milwaukee","May"] = results30
weather_df.loc["Albuquerque","May"] = results31
weather_df.loc["Tucson","May"] = results32
weather_df.loc["Fresno","May"] = results33
weather_df.loc["Mesa","May"] = results34
weather_df.loc["Sacramento","May"] = results35
weather_df.loc["Atlanta","May"] = results36
weather_df.loc["Kansas City","May"] = results37
weather_df.loc["Colorado Springs","May"] = results38
weather_df.loc["Omaha","May"] = results39

weather_df.loc["Raleigh","May"] = results40
weather_df.loc["Miami","May"] = results41
weather_df.loc["Long Beach","May"] = results42
weather_df.loc["Virginia Beach","May"] = results43
weather_df.loc["Oakland","May"] = results44
weather_df.loc["Minneapolis","May"] = results45
weather_df.loc["Tulsa","May"] = results46
weather_df.loc["Tampa","May"] = results47
weather_df.loc["Arlington","May"] = results48
weather_df.loc["New Orleans","May"] = results49

# %%
# results for June and each of the top 50 states
x = np.arange(0, 30, 1)
results0 = []
results1 = []
results2 = []
results3 = []
results4 = []
results5 = []
results6 = []
results7 = []
results8 = []
results9 = []
results10 = []
results11 = []
results12 = []
results13 = []
results14 = []
results15 = []
results16 = []
results17 = []
results18 = []
results19 = []
results20 = []
results21 = []
results22 = []
results23 = []
results24 = []
results25 = []
results26 = []
results27 = []
results28 = []
results29 = []
results30 = []
results31 = []
results32 = []
results33 = []
results34 = []
results35 = []
results36 = []
results37 = []
results38 = []
results39 = []
results40 = []
results41 = []
results42 = []
results43 = []
results44 = []
results45 = []
results46 = []
results47 = []
results48 = []
results49 = []

# Pulling all the average temps per day from each city
for x in x:
        results0.append(jun_data[0]["data"]["weather"][x]["avgtempF"])
        results1.append(jun_data[1]["data"]["weather"][x]["avgtempF"])
        results2.append(jun_data[2]["data"]["weather"][x]["avgtempF"])
        results3.append(jun_data[3]["data"]["weather"][x]["avgtempF"])
        results4.append(jun_data[4]["data"]["weather"][x]["avgtempF"])
        results5.append(jun_data[5]["data"]["weather"][x]["avgtempF"])
        results6.append(jun_data[6]["data"]["weather"][x]["avgtempF"])
        results7.append(jun_data[7]["data"]["weather"][x]["avgtempF"])
        results8.append(jun_data[8]["data"]["weather"][x]["avgtempF"])
        results9.append(jun_data[9]["data"]["weather"][x]["avgtempF"])
        results10.append(jun_data[10]["data"]["weather"][x]["avgtempF"])
        results11.append(jun_data[11]["data"]["weather"][x]["avgtempF"])
        results12.append(jun_data[12]["data"]["weather"][x]["avgtempF"])
        results13.append(jun_data[13]["data"]["weather"][x]["avgtempF"])
        results14.append(jun_data[14]["data"]["weather"][x]["avgtempF"])
        results15.append(jun_data[15]["data"]["weather"][x]["avgtempF"])
        results16.append(jun_data[16]["data"]["weather"][x]["avgtempF"])
        results17.append(jun_data[17]["data"]["weather"][x]["avgtempF"])
        results18.append(jun_data[18]["data"]["weather"][x]["avgtempF"])
        results19.append(jun_data[19]["data"]["weather"][x]["avgtempF"])
        results20.append(jun_data[20]["data"]["weather"][x]["avgtempF"])
        results21.append(jun_data[21]["data"]["weather"][x]["avgtempF"])
        results22.append(jun_data[22]["data"]["weather"][x]["avgtempF"])
        results23.append(jun_data[23]["data"]["weather"][x]["avgtempF"])
        results24.append(jun_data[24]["data"]["weather"][x]["avgtempF"])
        results25.append(jun_data[25]["data"]["weather"][x]["avgtempF"])
        results26.append(jun_data[26]["data"]["weather"][x]["avgtempF"])
        results27.append(jun_data[27]["data"]["weather"][x]["avgtempF"])
        results28.append(jun_data[28]["data"]["weather"][x]["avgtempF"])
        results29.append(jun_data[29]["data"]["weather"][x]["avgtempF"])
        results30.append(jun_data[30]["data"]["weather"][x]["avgtempF"])
        results31.append(jun_data[31]["data"]["weather"][x]["avgtempF"])
        results32.append(jun_data[32]["data"]["weather"][x]["avgtempF"])
        results33.append(jun_data[33]["data"]["weather"][x]["avgtempF"])
        results34.append(jun_data[34]["data"]["weather"][x]["avgtempF"])
        results35.append(jun_data[35]["data"]["weather"][x]["avgtempF"])
        results36.append(jun_data[36]["data"]["weather"][x]["avgtempF"])
        results37.append(jun_data[37]["data"]["weather"][x]["avgtempF"])
        results38.append(jun_data[38]["data"]["weather"][x]["avgtempF"])
        results39.append(jun_data[39]["data"]["weather"][x]["avgtempF"])
        results40.append(jun_data[40]["data"]["weather"][x]["avgtempF"])
        results41.append(jun_data[41]["data"]["weather"][x]["avgtempF"])
        results42.append(jun_data[42]["data"]["weather"][x]["avgtempF"])
        results43.append(jun_data[43]["data"]["weather"][x]["avgtempF"])
        results44.append(jun_data[44]["data"]["weather"][x]["avgtempF"])
        results45.append(jun_data[45]["data"]["weather"][x]["avgtempF"])
        results46.append(jun_data[46]["data"]["weather"][x]["avgtempF"])
        results47.append(jun_data[47]["data"]["weather"][x]["avgtempF"])
        results48.append(jun_data[48]["data"]["weather"][x]["avgtempF"])
        results49.append(jun_data[49]["data"]["weather"][x]["avgtempF"])

# %%
# Putting all the data into the df
weather_df.loc["New York","June"] = results0
weather_df.loc["Los Angeles","June"] = results1
weather_df.loc["Chicago","June"] = results2
weather_df.loc["Houston","June"] = results3
weather_df.loc["Phoenix","June"] = results4
weather_df.loc["Philadelphia","June"] = results5
weather_df.loc["San Antonio","June"] = results6
weather_df.loc["San Diego","June"] = results7
weather_df.loc["Dallas","June"] = results8
weather_df.loc["San Jose","June"] = results9

weather_df.loc["Austin","June"] = results10
weather_df.loc["Jacksonville","June"] = results11
weather_df.loc["Fort Worth","June"] = results12
weather_df.loc["Columbus","June"] = results13
weather_df.loc["Charlotte","June"] = results14
weather_df.loc["San Francisco","June"] = results15
weather_df.loc["Indianapolis","June"] = results16
weather_df.loc["Seattle","June"] = results17
weather_df.loc["Denver","June"] = results18
weather_df.loc["Washington","June"] = results19

weather_df.loc["Boston","June"] = results20
weather_df.loc["El Paso","June"] = results21
weather_df.loc["Nashville","June"] = results22
weather_df.loc["Detroit","June"] = results23
weather_df.loc["Oklahoma City","June"] = results24
weather_df.loc["Portland","June"] = results25
weather_df.loc["Las Vegas","June"] = results26
weather_df.loc["Memphis","June"] = results27
weather_df.loc["Louisville","June"] = results28
weather_df.loc["Baltimore","June"] = results29

weather_df.loc["Milwaukee","June"] = results30
weather_df.loc["Albuquerque","June"] = results31
weather_df.loc["Tucson","June"] = results32
weather_df.loc["Fresno","June"] = results33
weather_df.loc["Mesa","June"] = results34
weather_df.loc["Sacramento","June"] = results35
weather_df.loc["Atlanta","June"] = results36
weather_df.loc["Kansas City","June"] = results37
weather_df.loc["Colorado Springs","June"] = results38
weather_df.loc["Omaha","June"] = results39

weather_df.loc["Raleigh","June"] = results40
weather_df.loc["Miami","June"] = results41
weather_df.loc["Long Beach","June"] = results42
weather_df.loc["Virginia Beach","June"] = results43
weather_df.loc["Oakland","June"] = results44
weather_df.loc["Minneapolis","June"] = results45
weather_df.loc["Tulsa","June"] = results46
weather_df.loc["Tampa","June"] = results47
weather_df.loc["Arlington","June"] = results48
weather_df.loc["New Orleans","June"] = results49

# %%
# results for July and each of the top 50 states
x = np.arange(0, 31, 1)
results0 = []
results1 = []
results2 = []
results3 = []
results4 = []
results5 = []
results6 = []
results7 = []
results8 = []
results9 = []
results10 = []
results11 = []
results12 = []
results13 = []
results14 = []
results15 = []
results16 = []
results17 = []
results18 = []
results19 = []
results20 = []
results21 = []
results22 = []
results23 = []
results24 = []
results25 = []
results26 = []
results27 = []
results28 = []
results29 = []
results30 = []
results31 = []
results32 = []
results33 = []
results34 = []
results35 = []
results36 = []
results37 = []
results38 = []
results39 = []
results40 = []
results41 = []
results42 = []
results43 = []
results44 = []
results45 = []
results46 = []
results47 = []
results48 = []
results49 = []

# Pulling all the average temps per day from each city
for x in x:
        results0.append(jul_data[0]["data"]["weather"][x]["avgtempF"])
        results1.append(jul_data[1]["data"]["weather"][x]["avgtempF"])
        results2.append(jul_data[2]["data"]["weather"][x]["avgtempF"])
        results3.append(jul_data[3]["data"]["weather"][x]["avgtempF"])
        results4.append(jul_data[4]["data"]["weather"][x]["avgtempF"])
        results5.append(jul_data[5]["data"]["weather"][x]["avgtempF"])
        results6.append(jul_data[6]["data"]["weather"][x]["avgtempF"])
        results7.append(jul_data[7]["data"]["weather"][x]["avgtempF"])
        results8.append(jul_data[8]["data"]["weather"][x]["avgtempF"])
        results9.append(jul_data[9]["data"]["weather"][x]["avgtempF"])
        results10.append(jul_data[10]["data"]["weather"][x]["avgtempF"])
        results11.append(jul_data[11]["data"]["weather"][x]["avgtempF"])
        results12.append(jul_data[12]["data"]["weather"][x]["avgtempF"])
        results13.append(jul_data[13]["data"]["weather"][x]["avgtempF"])
        results14.append(jul_data[14]["data"]["weather"][x]["avgtempF"])
        results15.append(jul_data[15]["data"]["weather"][x]["avgtempF"])
        results16.append(jul_data[16]["data"]["weather"][x]["avgtempF"])
        results17.append(jul_data[17]["data"]["weather"][x]["avgtempF"])
        results18.append(jul_data[18]["data"]["weather"][x]["avgtempF"])
        results19.append(jul_data[19]["data"]["weather"][x]["avgtempF"])
        results20.append(jul_data[20]["data"]["weather"][x]["avgtempF"])
        results21.append(jul_data[21]["data"]["weather"][x]["avgtempF"])
        results22.append(jul_data[22]["data"]["weather"][x]["avgtempF"])
        results23.append(jul_data[23]["data"]["weather"][x]["avgtempF"])
        results24.append(jul_data[24]["data"]["weather"][x]["avgtempF"])
        results25.append(jul_data[25]["data"]["weather"][x]["avgtempF"])
        results26.append(jul_data[26]["data"]["weather"][x]["avgtempF"])
        results27.append(jul_data[27]["data"]["weather"][x]["avgtempF"])
        results28.append(jul_data[28]["data"]["weather"][x]["avgtempF"])
        results29.append(jul_data[29]["data"]["weather"][x]["avgtempF"])
        results30.append(jul_data[30]["data"]["weather"][x]["avgtempF"])
        results31.append(jul_data[31]["data"]["weather"][x]["avgtempF"])
        results32.append(jul_data[32]["data"]["weather"][x]["avgtempF"])
        results33.append(jul_data[33]["data"]["weather"][x]["avgtempF"])
        results34.append(jul_data[34]["data"]["weather"][x]["avgtempF"])
        results35.append(jul_data[35]["data"]["weather"][x]["avgtempF"])
        results36.append(jul_data[36]["data"]["weather"][x]["avgtempF"])
        results37.append(jul_data[37]["data"]["weather"][x]["avgtempF"])
        results38.append(jul_data[38]["data"]["weather"][x]["avgtempF"])
        results39.append(jul_data[39]["data"]["weather"][x]["avgtempF"])
        results40.append(jul_data[40]["data"]["weather"][x]["avgtempF"])
        results41.append(jul_data[41]["data"]["weather"][x]["avgtempF"])
        results42.append(jul_data[42]["data"]["weather"][x]["avgtempF"])
        results43.append(jul_data[43]["data"]["weather"][x]["avgtempF"])
        results44.append(jul_data[44]["data"]["weather"][x]["avgtempF"])
        results45.append(jul_data[45]["data"]["weather"][x]["avgtempF"])
        results46.append(jul_data[46]["data"]["weather"][x]["avgtempF"])
        results47.append(jul_data[47]["data"]["weather"][x]["avgtempF"])
        results48.append(jul_data[48]["data"]["weather"][x]["avgtempF"])
        results49.append(jul_data[49]["data"]["weather"][x]["avgtempF"])

# %%
# Putting all the data into the df
weather_df.loc["New York","July"] = results0
weather_df.loc["Los Angeles","July"] = results1
weather_df.loc["Chicago","July"] = results2
weather_df.loc["Houston","July"] = results3
weather_df.loc["Phoenix","July"] = results4
weather_df.loc["Philadelphia","July"] = results5
weather_df.loc["San Antonio","July"] = results6
weather_df.loc["San Diego","July"] = results7
weather_df.loc["Dallas","July"] = results8
weather_df.loc["San Jose","July"] = results9

weather_df.loc["Austin","July"] = results10
weather_df.loc["Jacksonville","July"] = results11
weather_df.loc["Fort Worth","July"] = results12
weather_df.loc["Columbus","July"] = results13
weather_df.loc["Charlotte","July"] = results14
weather_df.loc["San Francisco","July"] = results15
weather_df.loc["Indianapolis","July"] = results16
weather_df.loc["Seattle","July"] = results17
weather_df.loc["Denver","July"] = results18
weather_df.loc["Washington","July"] = results19

weather_df.loc["Boston","July"] = results20
weather_df.loc["El Paso","July"] = results21
weather_df.loc["Nashville","July"] = results22
weather_df.loc["Detroit","July"] = results23
weather_df.loc["Oklahoma City","July"] = results24
weather_df.loc["Portland","July"] = results25
weather_df.loc["Las Vegas","July"] = results26
weather_df.loc["Memphis","July"] = results27
weather_df.loc["Louisville","July"] = results28
weather_df.loc["Baltimore","July"] = results29

weather_df.loc["Milwaukee","July"] = results30
weather_df.loc["Albuquerque","July"] = results31
weather_df.loc["Tucson","July"] = results32
weather_df.loc["Fresno","July"] = results33
weather_df.loc["Mesa","July"] = results34
weather_df.loc["Sacramento","July"] = results35
weather_df.loc["Atlanta","July"] = results36
weather_df.loc["Kansas City","July"] = results37
weather_df.loc["Colorado Springs","July"] = results38
weather_df.loc["Omaha","July"] = results39

weather_df.loc["Raleigh","July"] = results40
weather_df.loc["Miami","July"] = results41
weather_df.loc["Long Beach","July"] = results42
weather_df.loc["Virginia Beach","July"] = results43
weather_df.loc["Oakland","July"] = results44
weather_df.loc["Minneapolis","July"] = results45
weather_df.loc["Tulsa","July"] = results46
weather_df.loc["Tampa","July"] = results47
weather_df.loc["Arlington","July"] = results48
weather_df.loc["New Orleans","July"] = results49

# %%
# results for August and each of the top 50 states
x = np.arange(0, 31, 1)
results0 = []
results1 = []
results2 = []
results3 = []
results4 = []
results5 = []
results6 = []
results7 = []
results8 = []
results9 = []
results10 = []
results11 = []
results12 = []
results13 = []
results14 = []
results15 = []
results16 = []
results17 = []
results18 = []
results19 = []
results20 = []
results21 = []
results22 = []
results23 = []
results24 = []
results25 = []
results26 = []
results27 = []
results28 = []
results29 = []
results30 = []
results31 = []
results32 = []
results33 = []
results34 = []
results35 = []
results36 = []
results37 = []
results38 = []
results39 = []
results40 = []
results41 = []
results42 = []
results43 = []
results44 = []
results45 = []
results46 = []
results47 = []
results48 = []
results49 = []

# Pulling all the average temps per day from each city
for x in x:
        results0.append(aug_data[0]["data"]["weather"][x]["avgtempF"])
        results1.append(aug_data[1]["data"]["weather"][x]["avgtempF"])
        results2.append(aug_data[2]["data"]["weather"][x]["avgtempF"])
        results3.append(aug_data[3]["data"]["weather"][x]["avgtempF"])
        results4.append(aug_data[4]["data"]["weather"][x]["avgtempF"])
        results5.append(aug_data[5]["data"]["weather"][x]["avgtempF"])
        results6.append(aug_data[6]["data"]["weather"][x]["avgtempF"])
        results7.append(aug_data[7]["data"]["weather"][x]["avgtempF"])
        results8.append(aug_data[8]["data"]["weather"][x]["avgtempF"])
        results9.append(aug_data[9]["data"]["weather"][x]["avgtempF"])
        results10.append(aug_data[10]["data"]["weather"][x]["avgtempF"])
        results11.append(aug_data[11]["data"]["weather"][x]["avgtempF"])
        results12.append(aug_data[12]["data"]["weather"][x]["avgtempF"])
        results13.append(aug_data[13]["data"]["weather"][x]["avgtempF"])
        results14.append(aug_data[14]["data"]["weather"][x]["avgtempF"])
        results15.append(aug_data[15]["data"]["weather"][x]["avgtempF"])
        results16.append(aug_data[16]["data"]["weather"][x]["avgtempF"])
        results17.append(aug_data[17]["data"]["weather"][x]["avgtempF"])
        results18.append(aug_data[18]["data"]["weather"][x]["avgtempF"])
        results19.append(aug_data[19]["data"]["weather"][x]["avgtempF"])
        results20.append(aug_data[20]["data"]["weather"][x]["avgtempF"])
        results21.append(aug_data[21]["data"]["weather"][x]["avgtempF"])
        results22.append(aug_data[22]["data"]["weather"][x]["avgtempF"])
        results23.append(aug_data[23]["data"]["weather"][x]["avgtempF"])
        results24.append(aug_data[24]["data"]["weather"][x]["avgtempF"])
        results25.append(aug_data[25]["data"]["weather"][x]["avgtempF"])
        results26.append(aug_data[26]["data"]["weather"][x]["avgtempF"])
        results27.append(aug_data[27]["data"]["weather"][x]["avgtempF"])
        results28.append(aug_data[28]["data"]["weather"][x]["avgtempF"])
        results29.append(aug_data[29]["data"]["weather"][x]["avgtempF"])
        results30.append(aug_data[30]["data"]["weather"][x]["avgtempF"])
        results31.append(aug_data[31]["data"]["weather"][x]["avgtempF"])
        results32.append(aug_data[32]["data"]["weather"][x]["avgtempF"])
        results33.append(aug_data[33]["data"]["weather"][x]["avgtempF"])
        results34.append(aug_data[34]["data"]["weather"][x]["avgtempF"])
        results35.append(aug_data[35]["data"]["weather"][x]["avgtempF"])
        results36.append(aug_data[36]["data"]["weather"][x]["avgtempF"])
        results37.append(aug_data[37]["data"]["weather"][x]["avgtempF"])
        results38.append(aug_data[38]["data"]["weather"][x]["avgtempF"])
        results39.append(aug_data[39]["data"]["weather"][x]["avgtempF"])
        results40.append(aug_data[40]["data"]["weather"][x]["avgtempF"])
        results41.append(aug_data[41]["data"]["weather"][x]["avgtempF"])
        results42.append(aug_data[42]["data"]["weather"][x]["avgtempF"])
        results43.append(aug_data[43]["data"]["weather"][x]["avgtempF"])
        results44.append(aug_data[44]["data"]["weather"][x]["avgtempF"])
        results45.append(aug_data[45]["data"]["weather"][x]["avgtempF"])
        results46.append(aug_data[46]["data"]["weather"][x]["avgtempF"])
        results47.append(aug_data[47]["data"]["weather"][x]["avgtempF"])
        results48.append(aug_data[48]["data"]["weather"][x]["avgtempF"])
        results49.append(aug_data[49]["data"]["weather"][x]["avgtempF"])

# %%
# Putting all the data into the df
weather_df.loc["New York","August"] = results0
weather_df.loc["Los Angeles","August"] = results1
weather_df.loc["Chicago","August"] = results2
weather_df.loc["Houston","August"] = results3
weather_df.loc["Phoenix","August"] = results4
weather_df.loc["Philadelphia","August"] = results5
weather_df.loc["San Antonio","August"] = results6
weather_df.loc["San Diego","August"] = results7
weather_df.loc["Dallas","August"] = results8
weather_df.loc["San Jose","August"] = results9

weather_df.loc["Austin","August"] = results10
weather_df.loc["Jacksonville","August"] = results11
weather_df.loc["Fort Worth","August"] = results12
weather_df.loc["Columbus","August"] = results13
weather_df.loc["Charlotte","August"] = results14
weather_df.loc["San Francisco","August"] = results15
weather_df.loc["Indianapolis","August"] = results16
weather_df.loc["Seattle","August"] = results17
weather_df.loc["Denver","August"] = results18
weather_df.loc["Washington","August"] = results19

weather_df.loc["Boston","August"] = results20
weather_df.loc["El Paso","August"] = results21
weather_df.loc["Nashville","August"] = results22
weather_df.loc["Detroit","August"] = results23
weather_df.loc["Oklahoma City","August"] = results24
weather_df.loc["Portland","August"] = results25
weather_df.loc["Las Vegas","August"] = results26
weather_df.loc["Memphis","August"] = results27
weather_df.loc["Louisville","August"] = results28
weather_df.loc["Baltimore","August"] = results29

weather_df.loc["Milwaukee","August"] = results30
weather_df.loc["Albuquerque","August"] = results31
weather_df.loc["Tucson","August"] = results32
weather_df.loc["Fresno","August"] = results33
weather_df.loc["Mesa","August"] = results34
weather_df.loc["Sacramento","August"] = results35
weather_df.loc["Atlanta","August"] = results36
weather_df.loc["Kansas City","August"] = results37
weather_df.loc["Colorado Springs","August"] = results38
weather_df.loc["Omaha","August"] = results39

weather_df.loc["Raleigh","August"] = results40
weather_df.loc["Miami","August"] = results41
weather_df.loc["Long Beach","August"] = results42
weather_df.loc["Virginia Beach","August"] = results43
weather_df.loc["Oakland","August"] = results44
weather_df.loc["Minneapolis","August"] = results45
weather_df.loc["Tulsa","August"] = results46
weather_df.loc["Tampa","August"] = results47
weather_df.loc["Arlington","August"] = results48
weather_df.loc["New Orleans","August"] = results49

# %%
# results for September and each of the top 50 states
x = np.arange(0, 30, 1)
results0 = []
results1 = []
results2 = []
results3 = []
results4 = []
results5 = []
results6 = []
results7 = []
results8 = []
results9 = []
results10 = []
results11 = []
results12 = []
results13 = []
results14 = []
results15 = []
results16 = []
results17 = []
results18 = []
results19 = []
results20 = []
results21 = []
results22 = []
results23 = []
results24 = []
results25 = []
results26 = []
results27 = []
results28 = []
results29 = []
results30 = []
results31 = []
results32 = []
results33 = []
results34 = []
results35 = []
results36 = []
results37 = []
results38 = []
results39 = []
results40 = []
results41 = []
results42 = []
results43 = []
results44 = []
results45 = []
results46 = []
results47 = []
results48 = []
results49 = []

# Pulling all the average temps per day from each city
for x in x:
        results0.append(sep_data[0]["data"]["weather"][x]["avgtempF"])
        results1.append(sep_data[1]["data"]["weather"][x]["avgtempF"])
        results2.append(sep_data[2]["data"]["weather"][x]["avgtempF"])
        results3.append(sep_data[3]["data"]["weather"][x]["avgtempF"])
        results4.append(sep_data[4]["data"]["weather"][x]["avgtempF"])
        results5.append(sep_data[5]["data"]["weather"][x]["avgtempF"])
        results6.append(sep_data[6]["data"]["weather"][x]["avgtempF"])
        results7.append(sep_data[7]["data"]["weather"][x]["avgtempF"])
        results8.append(sep_data[8]["data"]["weather"][x]["avgtempF"])
        results9.append(sep_data[9]["data"]["weather"][x]["avgtempF"])
        results10.append(sep_data[10]["data"]["weather"][x]["avgtempF"])
        results11.append(sep_data[11]["data"]["weather"][x]["avgtempF"])
        results12.append(sep_data[12]["data"]["weather"][x]["avgtempF"])
        results13.append(sep_data[13]["data"]["weather"][x]["avgtempF"])
        results14.append(sep_data[14]["data"]["weather"][x]["avgtempF"])
        results15.append(sep_data[15]["data"]["weather"][x]["avgtempF"])
        results16.append(sep_data[16]["data"]["weather"][x]["avgtempF"])
        results17.append(sep_data[17]["data"]["weather"][x]["avgtempF"])
        results18.append(sep_data[18]["data"]["weather"][x]["avgtempF"])
        results19.append(sep_data[19]["data"]["weather"][x]["avgtempF"])
        results20.append(sep_data[20]["data"]["weather"][x]["avgtempF"])
        results21.append(sep_data[21]["data"]["weather"][x]["avgtempF"])
        results22.append(sep_data[22]["data"]["weather"][x]["avgtempF"])
        results23.append(sep_data[23]["data"]["weather"][x]["avgtempF"])
        results24.append(sep_data[24]["data"]["weather"][x]["avgtempF"])
        results25.append(sep_data[25]["data"]["weather"][x]["avgtempF"])
        results26.append(sep_data[26]["data"]["weather"][x]["avgtempF"])
        results27.append(sep_data[27]["data"]["weather"][x]["avgtempF"])
        results28.append(sep_data[28]["data"]["weather"][x]["avgtempF"])
        results29.append(sep_data[29]["data"]["weather"][x]["avgtempF"])
        results30.append(sep_data[30]["data"]["weather"][x]["avgtempF"])
        results31.append(sep_data[31]["data"]["weather"][x]["avgtempF"])
        results32.append(sep_data[32]["data"]["weather"][x]["avgtempF"])
        results33.append(sep_data[33]["data"]["weather"][x]["avgtempF"])
        results34.append(sep_data[34]["data"]["weather"][x]["avgtempF"])
        results35.append(sep_data[35]["data"]["weather"][x]["avgtempF"])
        results36.append(sep_data[36]["data"]["weather"][x]["avgtempF"])
        results37.append(sep_data[37]["data"]["weather"][x]["avgtempF"])
        results38.append(sep_data[38]["data"]["weather"][x]["avgtempF"])
        results39.append(sep_data[39]["data"]["weather"][x]["avgtempF"])
        results40.append(sep_data[40]["data"]["weather"][x]["avgtempF"])
        results41.append(sep_data[41]["data"]["weather"][x]["avgtempF"])
        results42.append(sep_data[42]["data"]["weather"][x]["avgtempF"])
        results43.append(sep_data[43]["data"]["weather"][x]["avgtempF"])
        results44.append(sep_data[44]["data"]["weather"][x]["avgtempF"])
        results45.append(sep_data[45]["data"]["weather"][x]["avgtempF"])
        results46.append(sep_data[46]["data"]["weather"][x]["avgtempF"])
        results47.append(sep_data[47]["data"]["weather"][x]["avgtempF"])
        results48.append(sep_data[48]["data"]["weather"][x]["avgtempF"])
        results49.append(sep_data[49]["data"]["weather"][x]["avgtempF"])

# %%
# Putting all the data into the df
weather_df.loc["New York","September"] = results0
weather_df.loc["Los Angeles","September"] = results1
weather_df.loc["Chicago","September"] = results2
weather_df.loc["Houston","September"] = results3
weather_df.loc["Phoenix","September"] = results4
weather_df.loc["Philadelphia","September"] = results5
weather_df.loc["San Antonio","September"] = results6
weather_df.loc["San Diego","September"] = results7
weather_df.loc["Dallas","September"] = results8
weather_df.loc["San Jose","September"] = results9

weather_df.loc["Austin","September"] = results10
weather_df.loc["Jacksonville","September"] = results11
weather_df.loc["Fort Worth","September"] = results12
weather_df.loc["Columbus","September"] = results13
weather_df.loc["Charlotte","September"] = results14
weather_df.loc["San Francisco","September"] = results15
weather_df.loc["Indianapolis","September"] = results16
weather_df.loc["Seattle","September"] = results17
weather_df.loc["Denver","September"] = results18
weather_df.loc["Washington","September"] = results19

weather_df.loc["Boston","September"] = results20
weather_df.loc["El Paso","September"] = results21
weather_df.loc["Nashville","September"] = results22
weather_df.loc["Detroit","September"] = results23
weather_df.loc["Oklahoma City","September"] = results24
weather_df.loc["Portland","September"] = results25
weather_df.loc["Las Vegas","September"] = results26
weather_df.loc["Memphis","September"] = results27
weather_df.loc["Louisville","September"] = results28
weather_df.loc["Baltimore","September"] = results29

weather_df.loc["Milwaukee","September"] = results30
weather_df.loc["Albuquerque","September"] = results31
weather_df.loc["Tucson","September"] = results32
weather_df.loc["Fresno","September"] = results33
weather_df.loc["Mesa","September"] = results34
weather_df.loc["Sacramento","September"] = results35
weather_df.loc["Atlanta","September"] = results36
weather_df.loc["Kansas City","September"] = results37
weather_df.loc["Colorado Springs","September"] = results38
weather_df.loc["Omaha","September"] = results39

weather_df.loc["Raleigh","September"] = results40
weather_df.loc["Miami","September"] = results41
weather_df.loc["Long Beach","September"] = results42
weather_df.loc["Virginia Beach","September"] = results43
weather_df.loc["Oakland","September"] = results44
weather_df.loc["Minneapolis","September"] = results45
weather_df.loc["Tulsa","September"] = results46
weather_df.loc["Tampa","September"] = results47
weather_df.loc["Arlington","September"] = results48
weather_df.loc["New Orleans","September"] = results49

# %%
# results for October and each of the top 50 states
x = np.arange(0, 31, 1)
results0 = []
results1 = []
results2 = []
results3 = []
results4 = []
results5 = []
results6 = []
results7 = []
results8 = []
results9 = []
results10 = []
results11 = []
results12 = []
results13 = []
results14 = []
results15 = []
results16 = []
results17 = []
results18 = []
results19 = []
results20 = []
results21 = []
results22 = []
results23 = []
results24 = []
results25 = []
results26 = []
results27 = []
results28 = []
results29 = []
results30 = []
results31 = []
results32 = []
results33 = []
results34 = []
results35 = []
results36 = []
results37 = []
results38 = []
results39 = []
results40 = []
results41 = []
results42 = []
results43 = []
results44 = []
results45 = []
results46 = []
results47 = []
results48 = []
results49 = []

# Pulling all the average temps per day from each city
for x in x:
        results0.append(oct_data[0]["data"]["weather"][x]["avgtempF"])
        results1.append(oct_data[1]["data"]["weather"][x]["avgtempF"])
        results2.append(oct_data[2]["data"]["weather"][x]["avgtempF"])
        results3.append(oct_data[3]["data"]["weather"][x]["avgtempF"])
        results4.append(oct_data[4]["data"]["weather"][x]["avgtempF"])
        results5.append(oct_data[5]["data"]["weather"][x]["avgtempF"])
        results6.append(oct_data[6]["data"]["weather"][x]["avgtempF"])
        results7.append(oct_data[7]["data"]["weather"][x]["avgtempF"])
        results8.append(oct_data[8]["data"]["weather"][x]["avgtempF"])
        results9.append(oct_data[9]["data"]["weather"][x]["avgtempF"])
        results10.append(oct_data[10]["data"]["weather"][x]["avgtempF"])
        results11.append(oct_data[11]["data"]["weather"][x]["avgtempF"])
        results12.append(oct_data[12]["data"]["weather"][x]["avgtempF"])
        results13.append(oct_data[13]["data"]["weather"][x]["avgtempF"])
        results14.append(oct_data[14]["data"]["weather"][x]["avgtempF"])
        results15.append(oct_data[15]["data"]["weather"][x]["avgtempF"])
        results16.append(oct_data[16]["data"]["weather"][x]["avgtempF"])
        results17.append(oct_data[17]["data"]["weather"][x]["avgtempF"])
        results18.append(oct_data[18]["data"]["weather"][x]["avgtempF"])
        results19.append(oct_data[19]["data"]["weather"][x]["avgtempF"])
        results20.append(oct_data[20]["data"]["weather"][x]["avgtempF"])
        results21.append(oct_data[21]["data"]["weather"][x]["avgtempF"])
        results22.append(oct_data[22]["data"]["weather"][x]["avgtempF"])
        results23.append(oct_data[23]["data"]["weather"][x]["avgtempF"])
        results24.append(oct_data[24]["data"]["weather"][x]["avgtempF"])
        results25.append(oct_data[25]["data"]["weather"][x]["avgtempF"])
        results26.append(oct_data[26]["data"]["weather"][x]["avgtempF"])
        results27.append(oct_data[27]["data"]["weather"][x]["avgtempF"])
        results28.append(oct_data[28]["data"]["weather"][x]["avgtempF"])
        results29.append(oct_data[29]["data"]["weather"][x]["avgtempF"])
        results30.append(oct_data[30]["data"]["weather"][x]["avgtempF"])
        results31.append(oct_data[31]["data"]["weather"][x]["avgtempF"])
        results32.append(oct_data[32]["data"]["weather"][x]["avgtempF"])
        results33.append(oct_data[33]["data"]["weather"][x]["avgtempF"])
        results34.append(oct_data[34]["data"]["weather"][x]["avgtempF"])
        results35.append(oct_data[35]["data"]["weather"][x]["avgtempF"])
        results36.append(oct_data[36]["data"]["weather"][x]["avgtempF"])
        results37.append(oct_data[37]["data"]["weather"][x]["avgtempF"])
        results38.append(oct_data[38]["data"]["weather"][x]["avgtempF"])
        results39.append(oct_data[39]["data"]["weather"][x]["avgtempF"])
        results40.append(oct_data[40]["data"]["weather"][x]["avgtempF"])
        results41.append(oct_data[41]["data"]["weather"][x]["avgtempF"])
        results42.append(oct_data[42]["data"]["weather"][x]["avgtempF"])
        results43.append(oct_data[43]["data"]["weather"][x]["avgtempF"])
        results44.append(oct_data[44]["data"]["weather"][x]["avgtempF"])
        results45.append(oct_data[45]["data"]["weather"][x]["avgtempF"])
        results46.append(oct_data[46]["data"]["weather"][x]["avgtempF"])
        results47.append(oct_data[47]["data"]["weather"][x]["avgtempF"])
        results48.append(oct_data[48]["data"]["weather"][x]["avgtempF"])
        results49.append(oct_data[49]["data"]["weather"][x]["avgtempF"])

# %%
# Putting all the data into the df
weather_df.loc["New York","October"] = results0
weather_df.loc["Los Angeles","October"] = results1
weather_df.loc["Chicago","October"] = results2
weather_df.loc["Houston","October"] = results3
weather_df.loc["Phoenix","October"] = results4
weather_df.loc["Philadelphia","October"] = results5
weather_df.loc["San Antonio","October"] = results6
weather_df.loc["San Diego","October"] = results7
weather_df.loc["Dallas","October"] = results8
weather_df.loc["San Jose","October"] = results9

weather_df.loc["Austin","October"] = results10
weather_df.loc["Jacksonville","October"] = results11
weather_df.loc["Fort Worth","October"] = results12
weather_df.loc["Columbus","October"] = results13
weather_df.loc["Charlotte","October"] = results14
weather_df.loc["San Francisco","October"] = results15
weather_df.loc["Indianapolis","October"] = results16
weather_df.loc["Seattle","October"] = results17
weather_df.loc["Denver","October"] = results18
weather_df.loc["Washington","October"] = results19

weather_df.loc["Boston","October"] = results20
weather_df.loc["El Paso","October"] = results21
weather_df.loc["Nashville","October"] = results22
weather_df.loc["Detroit","October"] = results23
weather_df.loc["Oklahoma City","October"] = results24
weather_df.loc["Portland","October"] = results25
weather_df.loc["Las Vegas","October"] = results26
weather_df.loc["Memphis","October"] = results27
weather_df.loc["Louisville","October"] = results28
weather_df.loc["Baltimore","October"] = results29

weather_df.loc["Milwaukee","October"] = results30
weather_df.loc["Albuquerque","October"] = results31
weather_df.loc["Tucson","October"] = results32
weather_df.loc["Fresno","October"] = results33
weather_df.loc["Mesa","October"] = results34
weather_df.loc["Sacramento","October"] = results35
weather_df.loc["Atlanta","October"] = results36
weather_df.loc["Kansas City","October"] = results37
weather_df.loc["Colorado Springs","October"] = results38
weather_df.loc["Omaha","October"] = results39

weather_df.loc["Raleigh","October"] = results40
weather_df.loc["Miami","October"] = results41
weather_df.loc["Long Beach","October"] = results42
weather_df.loc["Virginia Beach","October"] = results43
weather_df.loc["Oakland","October"] = results44
weather_df.loc["Minneapolis","October"] = results45
weather_df.loc["Tulsa","October"] = results46
weather_df.loc["Tampa","October"] = results47
weather_df.loc["Arlington","October"] = results48
weather_df.loc["New Orleans","October"] = results49

# %%
# results for November and each of the top 50 states
x = np.arange(0, 30, 1)
results0 = []
results1 = []
results2 = []
results3 = []
results4 = []
results5 = []
results6 = []
results7 = []
results8 = []
results9 = []
results10 = []
results11 = []
results12 = []
results13 = []
results14 = []
results15 = []
results16 = []
results17 = []
results18 = []
results19 = []
results20 = []
results21 = []
results22 = []
results23 = []
results24 = []
results25 = []
results26 = []
results27 = []
results28 = []
results29 = []
results30 = []
results31 = []
results32 = []
results33 = []
results34 = []
results35 = []
results36 = []
results37 = []
results38 = []
results39 = []
results40 = []
results41 = []
results42 = []
results43 = []
results44 = []
results45 = []
results46 = []
results47 = []
results48 = []
results49 = []

# Pulling all the average temps per day from each city
for x in x:
        results0.append(nov_data[0]["data"]["weather"][x]["avgtempF"])
        results1.append(nov_data[1]["data"]["weather"][x]["avgtempF"])
        results2.append(nov_data[2]["data"]["weather"][x]["avgtempF"])
        results3.append(nov_data[3]["data"]["weather"][x]["avgtempF"])
        results4.append(nov_data[4]["data"]["weather"][x]["avgtempF"])
        results5.append(nov_data[5]["data"]["weather"][x]["avgtempF"])
        results6.append(nov_data[6]["data"]["weather"][x]["avgtempF"])
        results7.append(nov_data[7]["data"]["weather"][x]["avgtempF"])
        results8.append(nov_data[8]["data"]["weather"][x]["avgtempF"])
        results9.append(nov_data[9]["data"]["weather"][x]["avgtempF"])
        results10.append(nov_data[10]["data"]["weather"][x]["avgtempF"])
        results11.append(nov_data[11]["data"]["weather"][x]["avgtempF"])
        results12.append(nov_data[12]["data"]["weather"][x]["avgtempF"])
        results13.append(nov_data[13]["data"]["weather"][x]["avgtempF"])
        results14.append(nov_data[14]["data"]["weather"][x]["avgtempF"])
        results15.append(nov_data[15]["data"]["weather"][x]["avgtempF"])
        results16.append(nov_data[16]["data"]["weather"][x]["avgtempF"])
        results17.append(nov_data[17]["data"]["weather"][x]["avgtempF"])
        results18.append(nov_data[18]["data"]["weather"][x]["avgtempF"])
        results19.append(nov_data[19]["data"]["weather"][x]["avgtempF"])
        results20.append(nov_data[20]["data"]["weather"][x]["avgtempF"])
        results21.append(nov_data[21]["data"]["weather"][x]["avgtempF"])
        results22.append(nov_data[22]["data"]["weather"][x]["avgtempF"])
        results23.append(nov_data[23]["data"]["weather"][x]["avgtempF"])
        results24.append(nov_data[24]["data"]["weather"][x]["avgtempF"])
        results25.append(nov_data[25]["data"]["weather"][x]["avgtempF"])
        results26.append(nov_data[26]["data"]["weather"][x]["avgtempF"])
        results27.append(nov_data[27]["data"]["weather"][x]["avgtempF"])
        results28.append(nov_data[28]["data"]["weather"][x]["avgtempF"])
        results29.append(nov_data[29]["data"]["weather"][x]["avgtempF"])
        results30.append(nov_data[30]["data"]["weather"][x]["avgtempF"])
        results31.append(nov_data[31]["data"]["weather"][x]["avgtempF"])
        results32.append(nov_data[32]["data"]["weather"][x]["avgtempF"])
        results33.append(nov_data[33]["data"]["weather"][x]["avgtempF"])
        results34.append(nov_data[34]["data"]["weather"][x]["avgtempF"])
        results35.append(nov_data[35]["data"]["weather"][x]["avgtempF"])
        results36.append(nov_data[36]["data"]["weather"][x]["avgtempF"])
        results37.append(nov_data[37]["data"]["weather"][x]["avgtempF"])
        results38.append(nov_data[38]["data"]["weather"][x]["avgtempF"])
        results39.append(nov_data[39]["data"]["weather"][x]["avgtempF"])
        results40.append(nov_data[40]["data"]["weather"][x]["avgtempF"])
        results41.append(nov_data[41]["data"]["weather"][x]["avgtempF"])
        results42.append(nov_data[42]["data"]["weather"][x]["avgtempF"])
        results43.append(nov_data[43]["data"]["weather"][x]["avgtempF"])
        results44.append(nov_data[44]["data"]["weather"][x]["avgtempF"])
        results45.append(nov_data[45]["data"]["weather"][x]["avgtempF"])
        results46.append(nov_data[46]["data"]["weather"][x]["avgtempF"])
        results47.append(nov_data[47]["data"]["weather"][x]["avgtempF"])
        results48.append(nov_data[48]["data"]["weather"][x]["avgtempF"])
        results49.append(nov_data[49]["data"]["weather"][x]["avgtempF"])

# %%
# Putting all the data into the df
weather_df.loc["New York","November"] = results0
weather_df.loc["Los Angeles","November"] = results1
weather_df.loc["Chicago","November"] = results2
weather_df.loc["Houston","November"] = results3
weather_df.loc["Phoenix","November"] = results4
weather_df.loc["Philadelphia","November"] = results5
weather_df.loc["San Antonio","November"] = results6
weather_df.loc["San Diego","November"] = results7
weather_df.loc["Dallas","November"] = results8
weather_df.loc["San Jose","November"] = results9

weather_df.loc["Austin","November"] = results10
weather_df.loc["Jacksonville","November"] = results11
weather_df.loc["Fort Worth","November"] = results12
weather_df.loc["Columbus","November"] = results13
weather_df.loc["Charlotte","November"] = results14
weather_df.loc["San Francisco","November"] = results15
weather_df.loc["Indianapolis","November"] = results16
weather_df.loc["Seattle","November"] = results17
weather_df.loc["Denver","November"] = results18
weather_df.loc["Washington","November"] = results19

weather_df.loc["Boston","November"] = results20
weather_df.loc["El Paso","November"] = results21
weather_df.loc["Nashville","November"] = results22
weather_df.loc["Detroit","November"] = results23
weather_df.loc["Oklahoma City","November"] = results24
weather_df.loc["Portland","November"] = results25
weather_df.loc["Las Vegas","November"] = results26
weather_df.loc["Memphis","November"] = results27
weather_df.loc["Louisville","November"] = results28
weather_df.loc["Baltimore","November"] = results29

weather_df.loc["Milwaukee","November"] = results30
weather_df.loc["Albuquerque","November"] = results31
weather_df.loc["Tucson","November"] = results32
weather_df.loc["Fresno","November"] = results33
weather_df.loc["Mesa","November"] = results34
weather_df.loc["Sacramento","November"] = results35
weather_df.loc["Atlanta","November"] = results36
weather_df.loc["Kansas City","November"] = results37
weather_df.loc["Colorado Springs","November"] = results38
weather_df.loc["Omaha","November"] = results39

weather_df.loc["Raleigh","November"] = results40
weather_df.loc["Miami","November"] = results41
weather_df.loc["Long Beach","November"] = results42
weather_df.loc["Virginia Beach","November"] = results43
weather_df.loc["Oakland","November"] = results44
weather_df.loc["Minneapolis","November"] = results45
weather_df.loc["Tulsa","November"] = results46
weather_df.loc["Tampa","November"] = results47
weather_df.loc["Arlington","November"] = results48
weather_df.loc["New Orleans","November"] = results49

# %%
# results for December and each of the top 50 states
x = np.arange(0, 31, 1)
results0 = []
results1 = []
results2 = []
results3 = []
results4 = []
results5 = []
results6 = []
results7 = []
results8 = []
results9 = []
results10 = []
results11 = []
results12 = []
results13 = []
results14 = []
results15 = []
results16 = []
results17 = []
results18 = []
results19 = []
results20 = []
results21 = []
results22 = []
results23 = []
results24 = []
results25 = []
results26 = []
results27 = []
results28 = []
results29 = []
results30 = []
results31 = []
results32 = []
results33 = []
results34 = []
results35 = []
results36 = []
results37 = []
results38 = []
results39 = []
results40 = []
results41 = []
results42 = []
results43 = []
results44 = []
results45 = []
results46 = []
results47 = []
results48 = []
results49 = []

# Pulling all the average temps per day from each city
for x in x:
        results0.append(dec_data[0]["data"]["weather"][x]["avgtempF"])
        results1.append(dec_data[1]["data"]["weather"][x]["avgtempF"])
        results2.append(dec_data[2]["data"]["weather"][x]["avgtempF"])
        results3.append(dec_data[3]["data"]["weather"][x]["avgtempF"])
        results4.append(dec_data[4]["data"]["weather"][x]["avgtempF"])
        results5.append(dec_data[5]["data"]["weather"][x]["avgtempF"])
        results6.append(dec_data[6]["data"]["weather"][x]["avgtempF"])
        results7.append(dec_data[7]["data"]["weather"][x]["avgtempF"])
        results8.append(dec_data[8]["data"]["weather"][x]["avgtempF"])
        results9.append(dec_data[9]["data"]["weather"][x]["avgtempF"])
        results10.append(dec_data[10]["data"]["weather"][x]["avgtempF"])
        results11.append(dec_data[11]["data"]["weather"][x]["avgtempF"])
        results12.append(dec_data[12]["data"]["weather"][x]["avgtempF"])
        results13.append(dec_data[13]["data"]["weather"][x]["avgtempF"])
        results14.append(dec_data[14]["data"]["weather"][x]["avgtempF"])
        results15.append(dec_data[15]["data"]["weather"][x]["avgtempF"])
        results16.append(dec_data[16]["data"]["weather"][x]["avgtempF"])
        results17.append(dec_data[17]["data"]["weather"][x]["avgtempF"])
        results18.append(dec_data[18]["data"]["weather"][x]["avgtempF"])
        results19.append(dec_data[19]["data"]["weather"][x]["avgtempF"])
        results20.append(dec_data[20]["data"]["weather"][x]["avgtempF"])
        results21.append(dec_data[21]["data"]["weather"][x]["avgtempF"])
        results22.append(dec_data[22]["data"]["weather"][x]["avgtempF"])
        results23.append(dec_data[23]["data"]["weather"][x]["avgtempF"])
        results24.append(dec_data[24]["data"]["weather"][x]["avgtempF"])
        results25.append(dec_data[25]["data"]["weather"][x]["avgtempF"])
        results26.append(dec_data[26]["data"]["weather"][x]["avgtempF"])
        results27.append(dec_data[27]["data"]["weather"][x]["avgtempF"])
        results28.append(dec_data[28]["data"]["weather"][x]["avgtempF"])
        results29.append(dec_data[29]["data"]["weather"][x]["avgtempF"])
        results30.append(dec_data[30]["data"]["weather"][x]["avgtempF"])
        results31.append(dec_data[31]["data"]["weather"][x]["avgtempF"])
        results32.append(dec_data[32]["data"]["weather"][x]["avgtempF"])
        results33.append(dec_data[33]["data"]["weather"][x]["avgtempF"])
        results34.append(dec_data[34]["data"]["weather"][x]["avgtempF"])
        results35.append(dec_data[35]["data"]["weather"][x]["avgtempF"])
        results36.append(dec_data[36]["data"]["weather"][x]["avgtempF"])
        results37.append(dec_data[37]["data"]["weather"][x]["avgtempF"])
        results38.append(dec_data[38]["data"]["weather"][x]["avgtempF"])
        results39.append(dec_data[39]["data"]["weather"][x]["avgtempF"])
        results40.append(dec_data[40]["data"]["weather"][x]["avgtempF"])
        results41.append(dec_data[41]["data"]["weather"][x]["avgtempF"])
        results42.append(dec_data[42]["data"]["weather"][x]["avgtempF"])
        results43.append(dec_data[43]["data"]["weather"][x]["avgtempF"])
        results44.append(dec_data[44]["data"]["weather"][x]["avgtempF"])
        results45.append(dec_data[45]["data"]["weather"][x]["avgtempF"])
        results46.append(dec_data[46]["data"]["weather"][x]["avgtempF"])
        results47.append(dec_data[47]["data"]["weather"][x]["avgtempF"])
        results48.append(dec_data[48]["data"]["weather"][x]["avgtempF"])
        results49.append(dec_data[49]["data"]["weather"][x]["avgtempF"])

# %%
# Putting all the data into the df
weather_df.loc["New York","December"] = results0
weather_df.loc["Los Angeles","December"] = results1
weather_df.loc["Chicago","December"] = results2
weather_df.loc["Houston","December"] = results3
weather_df.loc["Phoenix","December"] = results4
weather_df.loc["Philadelphia","December"] = results5
weather_df.loc["San Antonio","December"] = results6
weather_df.loc["San Diego","December"] = results7
weather_df.loc["Dallas","December"] = results8
weather_df.loc["San Jose","December"] = results9

weather_df.loc["Austin","December"] = results10
weather_df.loc["Jacksonville","December"] = results11
weather_df.loc["Fort Worth","December"] = results12
weather_df.loc["Columbus","December"] = results13
weather_df.loc["Charlotte","December"] = results14
weather_df.loc["San Francisco","December"] = results15
weather_df.loc["Indianapolis","December"] = results16
weather_df.loc["Seattle","December"] = results17
weather_df.loc["Denver","December"] = results18
weather_df.loc["Washington","December"] = results19

weather_df.loc["Boston","December"] = results20
weather_df.loc["El Paso","December"] = results21
weather_df.loc["Nashville","December"] = results22
weather_df.loc["Detroit","December"] = results23
weather_df.loc["Oklahoma City","December"] = results24
weather_df.loc["Portland","December"] = results25
weather_df.loc["Las Vegas","December"] = results26
weather_df.loc["Memphis","December"] = results27
weather_df.loc["Louisville","December"] = results28
weather_df.loc["Baltimore","December"] = results29

weather_df.loc["Milwaukee","December"] = results30
weather_df.loc["Albuquerque","December"] = results31
weather_df.loc["Tucson","December"] = results32
weather_df.loc["Fresno","December"] = results33
weather_df.loc["Mesa","December"] = results34
weather_df.loc["Sacramento","December"] = results35
weather_df.loc["Atlanta","December"] = results36
weather_df.loc["Kansas City","December"] = results37
weather_df.loc["Colorado Springs","December"] = results38
weather_df.loc["Omaha","December"] = results39

weather_df.loc["Raleigh","December"] = results40
weather_df.loc["Miami","December"] = results41
weather_df.loc["Long Beach","December"] = results42
weather_df.loc["Virginia Beach","December"] = results43
weather_df.loc["Oakland","December"] = results44
weather_df.loc["Minneapolis","December"] = results45
weather_df.loc["Tulsa","December"] = results46
weather_df.loc["Tampa","December"] = results47
weather_df.loc["Arlington","December"] = results48
weather_df.loc["New Orleans","December"] = results49

# %%
weather_df.to_csv(r'C:\Users\skm72\Desktop\Project Repo\Project-1\Stephen\Weather CSV\City Weather Data.csv')
