# %%
# Dependencies
import requests
import json
import pandas as pd
import numpy as np
import csv
import itertools

# API key
from config import api_key

with open(r'C:\Users\skm72\Desktop\Project Repo\Project-1\Stephen\Weather Json\Jan.json') as jan:
   jan_data = json.load(jan)
with open(r'C:\Users\skm72\Desktop\Project Repo\Project-1\Stephen\Weather Json\Feb.json') as feb:
   feb_data = json.load(feb)
with open(r'C:\Users\skm72\Desktop\Project Repo\Project-1\Stephen\Weather Json\Mar.json') as mar:
   mar_data = json.load(mar)
with open(r'C:\Users\skm72\Desktop\Project Repo\Project-1\Stephen\Weather Json\Apr.json') as apr:
   apr_data = json.load(apr)
with open(r'C:\Users\skm72\Desktop\Project Repo\Project-1\Stephen\Weather Json\May.json') as may:
   may_data = json.load(may)
with open(r'C:\Users\skm72\Desktop\Project Repo\Project-1\Stephen\Weather Json\Jun.json') as jun:
   jun_data = json.load(jun)
with open(r'C:\Users\skm72\Desktop\Project Repo\Project-1\Stephen\Weather Json\Jul.json') as jul:
   jul_data = json.load(jul)
with open(r'C:\Users\skm72\Desktop\Project Repo\Project-1\Stephen\Weather Json\Aug.json') as aug:
   aug_data = json.load(aug)
with open(r'C:\Users\skm72\Desktop\Project Repo\Project-1\Stephen\Weather Json\Sep.json') as sep:
   sep_data = json.load(sep)
with open(r'C:\Users\skm72\Desktop\Project Repo\Project-1\Stephen\Weather Json\Oct.json') as oct:
   oct_data = json.load(oct)
with open(r'C:\Users\skm72\Desktop\Project Repo\Project-1\Stephen\Weather Json\Nov.json') as nov:
   nov_data = json.load(nov)
with open(r'C:\Users\skm72\Desktop\Project Repo\Project-1\Stephen\Weather Json\Dec.json') as dec:
   dec_data = json.load(dec)

# %%
weather_df1 = {}
weather_df1 = pd.DataFrame(weather_df1)
weather_df1["January"] = ""

weather_df2 = {}
weather_df2 = pd.DataFrame(weather_df2)
weather_df2["February"] = ""

weather_df3 = {}
weather_df3 = pd.DataFrame(weather_df3)
weather_df3["March"] = ""

weather_df4 = {}
weather_df4 = pd.DataFrame(weather_df4)
weather_df4["April"] = ""

weather_df5 = {}
weather_df5 = pd.DataFrame(weather_df5)
weather_df5["May"] = ""

weather_df6 = {}
weather_df6 = pd.DataFrame(weather_df6)
weather_df6["June"] = ""

weather_df7 = {}
weather_df7 = pd.DataFrame(weather_df7)
weather_df7["July"] = ""

weather_df8 = {}
weather_df8 = pd.DataFrame(weather_df8)
weather_df8["August"] = ""

weather_df9 = {}
weather_df9 = pd.DataFrame(weather_df9)
weather_df9["September"] = ""

weather_df10 = {}
weather_df10 = pd.DataFrame(weather_df10)
weather_df10["October"] = ""

weather_df11 = {}
weather_df11 = pd.DataFrame(weather_df11)
weather_df11["November"] = ""

weather_df12 = {}
weather_df12 = pd.DataFrame(weather_df12)
weather_df12["December"] = ""

# %%
# results for January and each of the top 50 states
x = np.arange(0, 31, 1)
results0 = []
results1 = []
results2 = []
results3 = []
results4 = []
results5 = []
results6 = []
results7 = []
results8 = []
results9 = []

# Pulling all the average temps per day from each city
for x in x:
        results0.append(jan_data[0]["data"]["weather"][x]["avgtempF"])
        results1.append(jan_data[1]["data"]["weather"][x]["avgtempF"])
        results2.append(jan_data[2]["data"]["weather"][x]["avgtempF"])
        results3.append(jan_data[3]["data"]["weather"][x]["avgtempF"])
        results4.append(jan_data[4]["data"]["weather"][x]["avgtempF"])
        results5.append(jan_data[5]["data"]["weather"][x]["avgtempF"])
        results6.append(jan_data[6]["data"]["weather"][x]["avgtempF"])
        results7.append(jan_data[7]["data"]["weather"][x]["avgtempF"])
        results8.append(jan_data[8]["data"]["weather"][x]["avgtempF"])
        results9.append(jan_data[9]["data"]["weather"][x]["avgtempF"])

# %%
# Putting all the data into the df
weather_df1.loc["New York","January"] = results0
weather_df1.loc["Los Angeles","January"] = results1
weather_df1.loc["Chicago","January"] = results2
weather_df1.loc["Houston","January"] = results3
weather_df1.loc["Phoenix","January"] = results4
weather_df1.loc["Philadelphia","January"] = results5
weather_df1.loc["San Antonio","January"] = results6
weather_df1.loc["San Diego","January"] = results7
weather_df1.loc["Dallas","January"] = results8
weather_df1.loc["San Jose","January"] = results9

# %%
# results for February and each of the top 50 states
x = np.arange(0, 28, 1)
results0 = []
results1 = []
results2 = []
results3 = []
results4 = []
results5 = []
results6 = []
results7 = []
results8 = []
results9 = []

# Pulling all the average temps per day from each city
for x in x:
        results0.append(feb_data[0]["data"]["weather"][x]["avgtempF"])
        results1.append(feb_data[1]["data"]["weather"][x]["avgtempF"])
        results2.append(feb_data[2]["data"]["weather"][x]["avgtempF"])
        results3.append(feb_data[3]["data"]["weather"][x]["avgtempF"])
        results4.append(feb_data[4]["data"]["weather"][x]["avgtempF"])
        results5.append(feb_data[5]["data"]["weather"][x]["avgtempF"])
        results6.append(feb_data[6]["data"]["weather"][x]["avgtempF"])
        results7.append(feb_data[7]["data"]["weather"][x]["avgtempF"])
        results8.append(feb_data[8]["data"]["weather"][x]["avgtempF"])
        results9.append(feb_data[9]["data"]["weather"][x]["avgtempF"])

# %%
# Putting all the data into the df
weather_df2.loc["New York","February"] = results0
weather_df2.loc["Los Angeles","February"] = results1
weather_df2.loc["Chicago","February"] = results2
weather_df2.loc["Houston","February"] = results3
weather_df2.loc["Phoenix","February"] = results4
weather_df2.loc["Philadelphia","February"] = results5
weather_df2.loc["San Antonio","February"] = results6
weather_df2.loc["San Diego","February"] = results7
weather_df2.loc["Dallas","February"] = results8
weather_df2.loc["San Jose","February"] = results9

weather_df2.loc["Austin","February"] = results10
weather_df2.loc["Jacksonville","February"] = results11
weather_df2.loc["Fort Worth","February"] = results12
weather_df2.loc["Columbus","February"] = results13
weather_df2.loc["Charlotte","February"] = results14
weather_df2.loc["San Francisco","February"] = results15
weather_df2.loc["Indianapolis","February"] = results16
weather_df2.loc["Seattle","February"] = results17
weather_df2.loc["Denver","February"] = results18
weather_df2.loc["Washington","February"] = results19

weather_df2.loc["Boston","February"] = results20
weather_df2.loc["El Paso","February"] = results21
weather_df2.loc["Nashville","February"] = results22
weather_df2.loc["Detroit","February"] = results23
weather_df2.loc["Oklahoma City","February"] = results24
weather_df2.loc["Portland","February"] = results25
weather_df2.loc["Las Vegas","February"] = results26
weather_df2.loc["Memphis","February"] = results27
weather_df2.loc["Louisville","February"] = results28
weather_df2.loc["Baltimore","February"] = results29

weather_df2.loc["Milwaukee","February"] = results30
weather_df2.loc["Albuquerque","February"] = results31
weather_df2.loc["Tucson","February"] = results32
weather_df2.loc["Fresno","February"] = results33
weather_df2.loc["Mesa","February"] = results34
weather_df2.loc["Sacramento","February"] = results35
weather_df2.loc["Atlanta","February"] = results36
weather_df2.loc["Kansas City","February"] = results37
weather_df2.loc["Colorado Springs","February"] = results38
weather_df2.loc["Omaha","February"] = results39

weather_df2.loc["Raleigh","February"] = results40
weather_df2.loc["Miami","February"] = results41
weather_df2.loc["Long Beach","February"] = results42
weather_df2.loc["Virginia Beach","February"] = results43
weather_df2.loc["Oakland","February"] = results44
weather_df2.loc["Minneapolis","February"] = results45
weather_df2.loc["Tulsa","February"] = results46
weather_df2.loc["Tampa","February"] = results47
weather_df2.loc["Arlington","February"] = results48
weather_df2.loc["New Orleans","February"] = results49

# %%
# results for March and each of the top 50 states
x = np.arange(0, 31, 1)
results0 = []
results1 = []
results2 = []
results3 = []
results4 = []
results5 = []
results6 = []
results7 = []
results8 = []
results9 = []
results10 = []
results11 = []
results12 = []
results13 = []
results14 = []
results15 = []
results16 = []
results17 = []
results18 = []
results19 = []
results20 = []
results21 = []
results22 = []
results23 = []
results24 = []
results25 = []
results26 = []
results27 = []
results28 = []
results29 = []
results30 = []
results31 = []
results32 = []
results33 = []
results34 = []
results35 = []
results36 = []
results37 = []
results38 = []
results39 = []
results40 = []
results41 = []
results42 = []
results43 = []
results44 = []
results45 = []
results46 = []
results47 = []
results48 = []
results49 = []

# Pulling all the average temps per day from each city
for x in x:
        results0.append(mar_data[0]["data"]["weather"][x]["avgtempF"])
        results1.append(mar_data[1]["data"]["weather"][x]["avgtempF"])
        results2.append(mar_data[2]["data"]["weather"][x]["avgtempF"])
        results3.append(mar_data[3]["data"]["weather"][x]["avgtempF"])
        results4.append(mar_data[4]["data"]["weather"][x]["avgtempF"])
        results5.append(mar_data[5]["data"]["weather"][x]["avgtempF"])
        results6.append(mar_data[6]["data"]["weather"][x]["avgtempF"])
        results7.append(mar_data[7]["data"]["weather"][x]["avgtempF"])
        results8.append(mar_data[8]["data"]["weather"][x]["avgtempF"])
        results9.append(mar_data[9]["data"]["weather"][x]["avgtempF"])
        results10.append(mar_data[10]["data"]["weather"][x]["avgtempF"])
        results11.append(mar_data[11]["data"]["weather"][x]["avgtempF"])
        results12.append(mar_data[12]["data"]["weather"][x]["avgtempF"])
        results13.append(mar_data[13]["data"]["weather"][x]["avgtempF"])
        results14.append(mar_data[14]["data"]["weather"][x]["avgtempF"])
        results15.append(mar_data[15]["data"]["weather"][x]["avgtempF"])
        results16.append(mar_data[16]["data"]["weather"][x]["avgtempF"])
        results17.append(mar_data[17]["data"]["weather"][x]["avgtempF"])
        results18.append(mar_data[18]["data"]["weather"][x]["avgtempF"])
        results19.append(mar_data[19]["data"]["weather"][x]["avgtempF"])
        results20.append(mar_data[20]["data"]["weather"][x]["avgtempF"])
        results21.append(mar_data[21]["data"]["weather"][x]["avgtempF"])
        results22.append(mar_data[22]["data"]["weather"][x]["avgtempF"])
        results23.append(mar_data[23]["data"]["weather"][x]["avgtempF"])
        results24.append(mar_data[24]["data"]["weather"][x]["avgtempF"])
        results25.append(mar_data[25]["data"]["weather"][x]["avgtempF"])
        results26.append(mar_data[26]["data"]["weather"][x]["avgtempF"])
        results27.append(mar_data[27]["data"]["weather"][x]["avgtempF"])
        results28.append(mar_data[28]["data"]["weather"][x]["avgtempF"])
        results29.append(mar_data[29]["data"]["weather"][x]["avgtempF"])
        results30.append(mar_data[30]["data"]["weather"][x]["avgtempF"])
        results31.append(mar_data[31]["data"]["weather"][x]["avgtempF"])
        results32.append(mar_data[32]["data"]["weather"][x]["avgtempF"])
        results33.append(mar_data[33]["data"]["weather"][x]["avgtempF"])
        results34.append(mar_data[34]["data"]["weather"][x]["avgtempF"])
        results35.append(mar_data[35]["data"]["weather"][x]["avgtempF"])
        results36.append(mar_data[36]["data"]["weather"][x]["avgtempF"])
        results37.append(mar_data[37]["data"]["weather"][x]["avgtempF"])
        results38.append(mar_data[38]["data"]["weather"][x]["avgtempF"])
        results39.append(mar_data[39]["data"]["weather"][x]["avgtempF"])
        results40.append(mar_data[40]["data"]["weather"][x]["avgtempF"])
        results41.append(mar_data[41]["data"]["weather"][x]["avgtempF"])
        results42.append(mar_data[42]["data"]["weather"][x]["avgtempF"])
        results43.append(mar_data[43]["data"]["weather"][x]["avgtempF"])
        results44.append(mar_data[44]["data"]["weather"][x]["avgtempF"])
        results45.append(mar_data[45]["data"]["weather"][x]["avgtempF"])
        results46.append(mar_data[46]["data"]["weather"][x]["avgtempF"])
        results47.append(mar_data[47]["data"]["weather"][x]["avgtempF"])
        results48.append(mar_data[48]["data"]["weather"][x]["avgtempF"])
        results49.append(mar_data[49]["data"]["weather"][x]["avgtempF"])

# %%
# Putting all the data into the df
weather_df3.loc["New York","March"] = results0
weather_df3.loc["Los Angeles","March"] = results1
weather_df3.loc["Chicago","March"] = results2
weather_df3.loc["Houston","March"] = results3
weather_df3.loc["Phoenix","March"] = results4
weather_df3.loc["Philadelphia","March"] = results5
weather_df3.loc["San Antonio","March"] = results6
weather_df3.loc["San Diego","March"] = results7
weather_df3.loc["Dallas","March"] = results8
weather_df3.loc["San Jose","March"] = results9

weather_df3.loc["Austin","March"] = results10
weather_df3.loc["Jacksonville","March"] = results11
weather_df3.loc["Fort Worth","March"] = results12
weather_df3.loc["Columbus","March"] = results13
weather_df3.loc["Charlotte","March"] = results14
weather_df3.loc["San Francisco","March"] = results15
weather_df3.loc["Indianapolis","March"] = results16
weather_df3.loc["Seattle","March"] = results17
weather_df3.loc["Denver","March"] = results18
weather_df3.loc["Washington","March"] = results19

weather_df3.loc["Boston","March"] = results20
weather_df3.loc["El Paso","March"] = results21
weather_df3.loc["Nashville","March"] = results22
weather_df3.loc["Detroit","March"] = results23
weather_df3.loc["Oklahoma City","March"] = results24
weather_df3.loc["Portland","March"] = results25
weather_df3.loc["Las Vegas","March"] = results26
weather_df3.loc["Memphis","March"] = results27
weather_df3.loc["Louisville","March"] = results28
weather_df3.loc["Baltimore","March"] = results29

weather_df3.loc["Milwaukee","March"] = results30
weather_df3.loc["Albuquerque","March"] = results31
weather_df3.loc["Tucson","March"] = results32
weather_df3.loc["Fresno","March"] = results33
weather_df3.loc["Mesa","March"] = results34
weather_df3.loc["Sacramento","March"] = results35
weather_df3.loc["Atlanta","March"] = results36
weather_df3.loc["Kansas City","March"] = results37
weather_df3.loc["Colorado Springs","March"] = results38
weather_df3.loc["Omaha","March"] = results39

weather_df3.loc["Raleigh","March"] = results40
weather_df3.loc["Miami","March"] = results41
weather_df3.loc["Long Beach","March"] = results42
weather_df3.loc["Virginia Beach","March"] = results43
weather_df3.loc["Oakland","March"] = results44
weather_df3.loc["Minneapolis","March"] = results45
weather_df3.loc["Tulsa","March"] = results46
weather_df3.loc["Tampa","March"] = results47
weather_df3.loc["Arlington","March"] = results48
weather_df3.loc["New Orleans","March"] = results49

# %%
# results for April and each of the top 50 states
x = np.arange(0, 30, 1)
results0 = []
results1 = []
results2 = []
results3 = []
results4 = []
results5 = []
results6 = []
results7 = []
results8 = []
results9 = []
results10 = []
results11 = []
results12 = []
results13 = []
results14 = []
results15 = []
results16 = []
results17 = []
results18 = []
results19 = []
results20 = []
results21 = []
results22 = []
results23 = []
results24 = []
results25 = []
results26 = []
results27 = []
results28 = []
results29 = []
results30 = []
results31 = []
results32 = []
results33 = []
results34 = []
results35 = []
results36 = []
results37 = []
results38 = []
results39 = []
results40 = []
results41 = []
results42 = []
results43 = []
results44 = []
results45 = []
results46 = []
results47 = []
results48 = []
results49 = []

# Pulling all the average temps per day from each city
for x in x:
        results0.append(apr_data[0]["data"]["weather"][x]["avgtempF"])
        results1.append(apr_data[1]["data"]["weather"][x]["avgtempF"])
        results2.append(apr_data[2]["data"]["weather"][x]["avgtempF"])
        results3.append(apr_data[3]["data"]["weather"][x]["avgtempF"])
        results4.append(apr_data[4]["data"]["weather"][x]["avgtempF"])
        results5.append(apr_data[5]["data"]["weather"][x]["avgtempF"])
        results6.append(apr_data[6]["data"]["weather"][x]["avgtempF"])
        results7.append(apr_data[7]["data"]["weather"][x]["avgtempF"])
        results8.append(apr_data[8]["data"]["weather"][x]["avgtempF"])
        results9.append(apr_data[9]["data"]["weather"][x]["avgtempF"])
        results10.append(apr_data[10]["data"]["weather"][x]["avgtempF"])
        results11.append(apr_data[11]["data"]["weather"][x]["avgtempF"])
        results12.append(apr_data[12]["data"]["weather"][x]["avgtempF"])
        results13.append(apr_data[13]["data"]["weather"][x]["avgtempF"])
        results14.append(apr_data[14]["data"]["weather"][x]["avgtempF"])
        results15.append(apr_data[15]["data"]["weather"][x]["avgtempF"])
        results16.append(apr_data[16]["data"]["weather"][x]["avgtempF"])
        results17.append(apr_data[17]["data"]["weather"][x]["avgtempF"])
        results18.append(apr_data[18]["data"]["weather"][x]["avgtempF"])
        results19.append(apr_data[19]["data"]["weather"][x]["avgtempF"])
        results20.append(apr_data[20]["data"]["weather"][x]["avgtempF"])
        results21.append(apr_data[21]["data"]["weather"][x]["avgtempF"])
        results22.append(apr_data[22]["data"]["weather"][x]["avgtempF"])
        results23.append(apr_data[23]["data"]["weather"][x]["avgtempF"])
        results24.append(apr_data[24]["data"]["weather"][x]["avgtempF"])
        results25.append(apr_data[25]["data"]["weather"][x]["avgtempF"])
        results26.append(apr_data[26]["data"]["weather"][x]["avgtempF"])
        results27.append(apr_data[27]["data"]["weather"][x]["avgtempF"])
        results28.append(apr_data[28]["data"]["weather"][x]["avgtempF"])
        results29.append(apr_data[29]["data"]["weather"][x]["avgtempF"])
        results30.append(apr_data[30]["data"]["weather"][x]["avgtempF"])
        results31.append(apr_data[31]["data"]["weather"][x]["avgtempF"])
        results32.append(apr_data[32]["data"]["weather"][x]["avgtempF"])
        results33.append(apr_data[33]["data"]["weather"][x]["avgtempF"])
        results34.append(apr_data[34]["data"]["weather"][x]["avgtempF"])
        results35.append(apr_data[35]["data"]["weather"][x]["avgtempF"])
        results36.append(apr_data[36]["data"]["weather"][x]["avgtempF"])
        results37.append(apr_data[37]["data"]["weather"][x]["avgtempF"])
        results38.append(apr_data[38]["data"]["weather"][x]["avgtempF"])
        results39.append(apr_data[39]["data"]["weather"][x]["avgtempF"])
        results40.append(apr_data[40]["data"]["weather"][x]["avgtempF"])
        results41.append(apr_data[41]["data"]["weather"][x]["avgtempF"])
        results42.append(apr_data[42]["data"]["weather"][x]["avgtempF"])
        results43.append(apr_data[43]["data"]["weather"][x]["avgtempF"])
        results44.append(apr_data[44]["data"]["weather"][x]["avgtempF"])
        results45.append(apr_data[45]["data"]["weather"][x]["avgtempF"])
        results46.append(apr_data[46]["data"]["weather"][x]["avgtempF"])
        results47.append(apr_data[47]["data"]["weather"][x]["avgtempF"])
        results48.append(apr_data[48]["data"]["weather"][x]["avgtempF"])
        results49.append(apr_data[49]["data"]["weather"][x]["avgtempF"])

# %%
# Putting all the data into the df
weather_df4.loc["New York","April"] = results0
weather_df4.loc["Los Angeles","April"] = results1
weather_df4.loc["Chicago","April"] = results2
weather_df4.loc["Houston","April"] = results3
weather_df4.loc["Phoenix","April"] = results4
weather_df4.loc["Philadelphia","April"] = results5
weather_df4.loc["San Antonio","April"] = results6
weather_df4.loc["San Diego","April"] = results7
weather_df4.loc["Dallas","April"] = results8
weather_df4.loc["San Jose","April"] = results9

weather_df4.loc["Austin","April"] = results10
weather_df4.loc["Jacksonville","April"] = results11
weather_df4.loc["Fort Worth","April"] = results12
weather_df4.loc["Columbus","April"] = results13
weather_df4.loc["Charlotte","April"] = results14
weather_df4.loc["San Francisco","April"] = results15
weather_df4.loc["Indianapolis","April"] = results16
weather_df4.loc["Seattle","April"] = results17
weather_df4.loc["Denver","April"] = results18
weather_df4.loc["Washington","April"] = results19

weather_df4.loc["Boston","April"] = results20
weather_df4.loc["El Paso","April"] = results21
weather_df4.loc["Nashville","April"] = results22
weather_df4.loc["Detroit","April"] = results23
weather_df4.loc["Oklahoma City","April"] = results24
weather_df4.loc["Portland","April"] = results25
weather_df4.loc["Las Vegas","April"] = results26
weather_df4.loc["Memphis","April"] = results27
weather_df4.loc["Louisville","April"] = results28
weather_df4.loc["Baltimore","April"] = results29

weather_df4.loc["Milwaukee","April"] = results30
weather_df4.loc["Albuquerque","April"] = results31
weather_df4.loc["Tucson","April"] = results32
weather_df4.loc["Fresno","April"] = results33
weather_df4.loc["Mesa","April"] = results34
weather_df4.loc["Sacramento","April"] = results35
weather_df4.loc["Atlanta","April"] = results36
weather_df4.loc["Kansas City","April"] = results37
weather_df4.loc["Colorado Springs","April"] = results38
weather_df4.loc["Omaha","April"] = results39

weather_df4.loc["Raleigh","April"] = results40
weather_df4.loc["Miami","April"] = results41
weather_df4.loc["Long Beach","April"] = results42
weather_df4.loc["Virginia Beach","April"] = results43
weather_df4.loc["Oakland","April"] = results44
weather_df4.loc["Minneapolis","April"] = results45
weather_df4.loc["Tulsa","April"] = results46
weather_df4.loc["Tampa","April"] = results47
weather_df4.loc["Arlington","April"] = results48
weather_df4.loc["New Orleans","April"] = results49

# %%
# results for May and each of the top 50 states
x = np.arange(0, 31, 1)
results0 = []
results1 = []
results2 = []
results3 = []
results4 = []
results5 = []
results6 = []
results7 = []
results8 = []
results9 = []
results10 = []
results11 = []
results12 = []
results13 = []
results14 = []
results15 = []
results16 = []
results17 = []
results18 = []
results19 = []
results20 = []
results21 = []
results22 = []
results23 = []
results24 = []
results25 = []
results26 = []
results27 = []
results28 = []
results29 = []
results30 = []
results31 = []
results32 = []
results33 = []
results34 = []
results35 = []
results36 = []
results37 = []
results38 = []
results39 = []
results40 = []
results41 = []
results42 = []
results43 = []
results44 = []
results45 = []
results46 = []
results47 = []
results48 = []
results49 = []

# Pulling all the average temps per day from each city
for x in x:
        results0.append(may_data[0]["data"]["weather"][x]["avgtempF"])
        results1.append(may_data[1]["data"]["weather"][x]["avgtempF"])
        results2.append(may_data[2]["data"]["weather"][x]["avgtempF"])
        results3.append(may_data[3]["data"]["weather"][x]["avgtempF"])
        results4.append(may_data[4]["data"]["weather"][x]["avgtempF"])
        results5.append(may_data[5]["data"]["weather"][x]["avgtempF"])
        results6.append(may_data[6]["data"]["weather"][x]["avgtempF"])
        results7.append(may_data[7]["data"]["weather"][x]["avgtempF"])
        results8.append(may_data[8]["data"]["weather"][x]["avgtempF"])
        results9.append(may_data[9]["data"]["weather"][x]["avgtempF"])
        results10.append(may_data[10]["data"]["weather"][x]["avgtempF"])
        results11.append(may_data[11]["data"]["weather"][x]["avgtempF"])
        results12.append(may_data[12]["data"]["weather"][x]["avgtempF"])
        results13.append(may_data[13]["data"]["weather"][x]["avgtempF"])
        results14.append(may_data[14]["data"]["weather"][x]["avgtempF"])
        results15.append(may_data[15]["data"]["weather"][x]["avgtempF"])
        results16.append(may_data[16]["data"]["weather"][x]["avgtempF"])
        results17.append(may_data[17]["data"]["weather"][x]["avgtempF"])
        results18.append(may_data[18]["data"]["weather"][x]["avgtempF"])
        results19.append(may_data[19]["data"]["weather"][x]["avgtempF"])
        results20.append(may_data[20]["data"]["weather"][x]["avgtempF"])
        results21.append(may_data[21]["data"]["weather"][x]["avgtempF"])
        results22.append(may_data[22]["data"]["weather"][x]["avgtempF"])
        results23.append(may_data[23]["data"]["weather"][x]["avgtempF"])
        results24.append(may_data[24]["data"]["weather"][x]["avgtempF"])
        results25.append(may_data[25]["data"]["weather"][x]["avgtempF"])
        results26.append(may_data[26]["data"]["weather"][x]["avgtempF"])
        results27.append(may_data[27]["data"]["weather"][x]["avgtempF"])
        results28.append(may_data[28]["data"]["weather"][x]["avgtempF"])
        results29.append(may_data[29]["data"]["weather"][x]["avgtempF"])
        results30.append(may_data[30]["data"]["weather"][x]["avgtempF"])
        results31.append(may_data[31]["data"]["weather"][x]["avgtempF"])
        results32.append(may_data[32]["data"]["weather"][x]["avgtempF"])
        results33.append(may_data[33]["data"]["weather"][x]["avgtempF"])
        results34.append(may_data[34]["data"]["weather"][x]["avgtempF"])
        results35.append(may_data[35]["data"]["weather"][x]["avgtempF"])
        results36.append(may_data[36]["data"]["weather"][x]["avgtempF"])
        results37.append(may_data[37]["data"]["weather"][x]["avgtempF"])
        results38.append(may_data[38]["data"]["weather"][x]["avgtempF"])
        results39.append(may_data[39]["data"]["weather"][x]["avgtempF"])
        results40.append(may_data[40]["data"]["weather"][x]["avgtempF"])
        results41.append(may_data[41]["data"]["weather"][x]["avgtempF"])
        results42.append(may_data[42]["data"]["weather"][x]["avgtempF"])
        results43.append(may_data[43]["data"]["weather"][x]["avgtempF"])
        results44.append(may_data[44]["data"]["weather"][x]["avgtempF"])
        results45.append(may_data[45]["data"]["weather"][x]["avgtempF"])
        results46.append(may_data[46]["data"]["weather"][x]["avgtempF"])
        results47.append(may_data[47]["data"]["weather"][x]["avgtempF"])
        results48.append(may_data[48]["data"]["weather"][x]["avgtempF"])
        results49.append(may_data[49]["data"]["weather"][x]["avgtempF"])

# %%
# Putting all the data into the df
weather_df5.loc["New York","May"] = results0
weather_df5.loc["Los Angeles","May"] = results1
weather_df5.loc["Chicago","May"] = results2
weather_df5.loc["Houston","May"] = results3
weather_df5.loc["Phoenix","May"] = results4
weather_df5.loc["Philadelphia","May"] = results5
weather_df5.loc["San Antonio","May"] = results6
weather_df5.loc["San Diego","May"] = results7
weather_df5.loc["Dallas","May"] = results8
weather_df5.loc["San Jose","May"] = results9

weather_df5.loc["Austin","May"] = results10
weather_df5.loc["Jacksonville","May"] = results11
weather_df5.loc["Fort Worth","May"] = results12
weather_df5.loc["Columbus","May"] = results13
weather_df5.loc["Charlotte","May"] = results14
weather_df5.loc["San Francisco","May"] = results15
weather_df5.loc["Indianapolis","May"] = results16
weather_df5.loc["Seattle","May"] = results17
weather_df5.loc["Denver","May"] = results18
weather_df5.loc["Washington","May"] = results19

weather_df5.loc["Boston","May"] = results20
weather_df5.loc["El Paso","May"] = results21
weather_df5.loc["Nashville","May"] = results22
weather_df5.loc["Detroit","May"] = results23
weather_df5.loc["Oklahoma City","May"] = results24
weather_df5.loc["Portland","May"] = results25
weather_df5.loc["Las Vegas","May"] = results26
weather_df5.loc["Memphis","May"] = results27
weather_df5.loc["Louisville","May"] = results28
weather_df5.loc["Baltimore","May"] = results29

weather_df5.loc["Milwaukee","May"] = results30
weather_df5.loc["Albuquerque","May"] = results31
weather_df5.loc["Tucson","May"] = results32
weather_df5.loc["Fresno","May"] = results33
weather_df5.loc["Mesa","May"] = results34
weather_df5.loc["Sacramento","May"] = results35
weather_df5.loc["Atlanta","May"] = results36
weather_df5.loc["Kansas City","May"] = results37
weather_df5.loc["Colorado Springs","May"] = results38
weather_df5.loc["Omaha","May"] = results39

weather_df5.loc["Raleigh","May"] = results40
weather_df5.loc["Miami","May"] = results41
weather_df5.loc["Long Beach","May"] = results42
weather_df5.loc["Virginia Beach","May"] = results43
weather_df5.loc["Oakland","May"] = results44
weather_df5.loc["Minneapolis","May"] = results45
weather_df5.loc["Tulsa","May"] = results46
weather_df5.loc["Tampa","May"] = results47
weather_df5.loc["Arlington","May"] = results48
weather_df5.loc["New Orleans","May"] = results49

# %%
# results for June and each of the top 50 states
x = np.arange(0, 30, 1)
results0 = []
results1 = []
results2 = []
results3 = []
results4 = []
results5 = []
results6 = []
results7 = []
results8 = []
results9 = []
results10 = []
results11 = []
results12 = []
results13 = []
results14 = []
results15 = []
results16 = []
results17 = []
results18 = []
results19 = []
results20 = []
results21 = []
results22 = []
results23 = []
results24 = []
results25 = []
results26 = []
results27 = []
results28 = []
results29 = []
results30 = []
results31 = []
results32 = []
results33 = []
results34 = []
results35 = []
results36 = []
results37 = []
results38 = []
results39 = []
results40 = []
results41 = []
results42 = []
results43 = []
results44 = []
results45 = []
results46 = []
results47 = []
results48 = []
results49 = []

# Pulling all the average temps per day from each city
for x in x:
        results0.append(jun_data[0]["data"]["weather"][x]["avgtempF"])
        results1.append(jun_data[1]["data"]["weather"][x]["avgtempF"])
        results2.append(jun_data[2]["data"]["weather"][x]["avgtempF"])
        results3.append(jun_data[3]["data"]["weather"][x]["avgtempF"])
        results4.append(jun_data[4]["data"]["weather"][x]["avgtempF"])
        results5.append(jun_data[5]["data"]["weather"][x]["avgtempF"])
        results6.append(jun_data[6]["data"]["weather"][x]["avgtempF"])
        results7.append(jun_data[7]["data"]["weather"][x]["avgtempF"])
        results8.append(jun_data[8]["data"]["weather"][x]["avgtempF"])
        results9.append(jun_data[9]["data"]["weather"][x]["avgtempF"])
        results10.append(jun_data[10]["data"]["weather"][x]["avgtempF"])
        results11.append(jun_data[11]["data"]["weather"][x]["avgtempF"])
        results12.append(jun_data[12]["data"]["weather"][x]["avgtempF"])
        results13.append(jun_data[13]["data"]["weather"][x]["avgtempF"])
        results14.append(jun_data[14]["data"]["weather"][x]["avgtempF"])
        results15.append(jun_data[15]["data"]["weather"][x]["avgtempF"])
        results16.append(jun_data[16]["data"]["weather"][x]["avgtempF"])
        results17.append(jun_data[17]["data"]["weather"][x]["avgtempF"])
        results18.append(jun_data[18]["data"]["weather"][x]["avgtempF"])
        results19.append(jun_data[19]["data"]["weather"][x]["avgtempF"])
        results20.append(jun_data[20]["data"]["weather"][x]["avgtempF"])
        results21.append(jun_data[21]["data"]["weather"][x]["avgtempF"])
        results22.append(jun_data[22]["data"]["weather"][x]["avgtempF"])
        results23.append(jun_data[23]["data"]["weather"][x]["avgtempF"])
        results24.append(jun_data[24]["data"]["weather"][x]["avgtempF"])
        results25.append(jun_data[25]["data"]["weather"][x]["avgtempF"])
        results26.append(jun_data[26]["data"]["weather"][x]["avgtempF"])
        results27.append(jun_data[27]["data"]["weather"][x]["avgtempF"])
        results28.append(jun_data[28]["data"]["weather"][x]["avgtempF"])
        results29.append(jun_data[29]["data"]["weather"][x]["avgtempF"])
        results30.append(jun_data[30]["data"]["weather"][x]["avgtempF"])
        results31.append(jun_data[31]["data"]["weather"][x]["avgtempF"])
        results32.append(jun_data[32]["data"]["weather"][x]["avgtempF"])
        results33.append(jun_data[33]["data"]["weather"][x]["avgtempF"])
        results34.append(jun_data[34]["data"]["weather"][x]["avgtempF"])
        results35.append(jun_data[35]["data"]["weather"][x]["avgtempF"])
        results36.append(jun_data[36]["data"]["weather"][x]["avgtempF"])
        results37.append(jun_data[37]["data"]["weather"][x]["avgtempF"])
        results38.append(jun_data[38]["data"]["weather"][x]["avgtempF"])
        results39.append(jun_data[39]["data"]["weather"][x]["avgtempF"])
        results40.append(jun_data[40]["data"]["weather"][x]["avgtempF"])
        results41.append(jun_data[41]["data"]["weather"][x]["avgtempF"])
        results42.append(jun_data[42]["data"]["weather"][x]["avgtempF"])
        results43.append(jun_data[43]["data"]["weather"][x]["avgtempF"])
        results44.append(jun_data[44]["data"]["weather"][x]["avgtempF"])
        results45.append(jun_data[45]["data"]["weather"][x]["avgtempF"])
        results46.append(jun_data[46]["data"]["weather"][x]["avgtempF"])
        results47.append(jun_data[47]["data"]["weather"][x]["avgtempF"])
        results48.append(jun_data[48]["data"]["weather"][x]["avgtempF"])
        results49.append(jun_data[49]["data"]["weather"][x]["avgtempF"])

# %%
# Putting all the data into the df
weather_df6.loc["New York","June"] = results0
weather_df6.loc["Los Angeles","June"] = results1
weather_df6.loc["Chicago","June"] = results2
weather_df6.loc["Houston","June"] = results3
weather_df6.loc["Phoenix","June"] = results4
weather_df6.loc["Philadelphia","June"] = results5
weather_df6.loc["San Antonio","June"] = results6
weather_df6.loc["San Diego","June"] = results7
weather_df6.loc["Dallas","June"] = results8
weather_df6.loc["San Jose","June"] = results9

weather_df6.loc["Austin","June"] = results10
weather_df6.loc["Jacksonville","June"] = results11
weather_df6.loc["Fort Worth","June"] = results12
weather_df6.loc["Columbus","June"] = results13
weather_df6.loc["Charlotte","June"] = results14
weather_df6.loc["San Francisco","June"] = results15
weather_df6.loc["Indianapolis","June"] = results16
weather_df6.loc["Seattle","June"] = results17
weather_df6.loc["Denver","June"] = results18
weather_df6.loc["Washington","June"] = results19

weather_df6.loc["Boston","June"] = results20
weather_df6.loc["El Paso","June"] = results21
weather_df6.loc["Nashville","June"] = results22
weather_df6.loc["Detroit","June"] = results23
weather_df6.loc["Oklahoma City","June"] = results24
weather_df6.loc["Portland","June"] = results25
weather_df6.loc["Las Vegas","June"] = results26
weather_df6.loc["Memphis","June"] = results27
weather_df6.loc["Louisville","June"] = results28
weather_df6.loc["Baltimore","June"] = results29

weather_df6.loc["Milwaukee","June"] = results30
weather_df6.loc["Albuquerque","June"] = results31
weather_df6.loc["Tucson","June"] = results32
weather_df6.loc["Fresno","June"] = results33
weather_df6.loc["Mesa","June"] = results34
weather_df6.loc["Sacramento","June"] = results35
weather_df6.loc["Atlanta","June"] = results36
weather_df6.loc["Kansas City","June"] = results37
weather_df6.loc["Colorado Springs","June"] = results38
weather_df6.loc["Omaha","June"] = results39

weather_df6.loc["Raleigh","June"] = results40
weather_df6.loc["Miami","June"] = results41
weather_df6.loc["Long Beach","June"] = results42
weather_df6.loc["Virginia Beach","June"] = results43
weather_df6.loc["Oakland","June"] = results44
weather_df6.loc["Minneapolis","June"] = results45
weather_df6.loc["Tulsa","June"] = results46
weather_df6.loc["Tampa","June"] = results47
weather_df6.loc["Arlington","June"] = results48
weather_df6.loc["New Orleans","June"] = results49

# %%
# results for July and each of the top 50 states
x = np.arange(0, 31, 1)
results0 = []
results1 = []
results2 = []
results3 = []
results4 = []
results5 = []
results6 = []
results7 = []
results8 = []
results9 = []
results10 = []
results11 = []
results12 = []
results13 = []
results14 = []
results15 = []
results16 = []
results17 = []
results18 = []
results19 = []
results20 = []
results21 = []
results22 = []
results23 = []
results24 = []
results25 = []
results26 = []
results27 = []
results28 = []
results29 = []
results30 = []
results31 = []
results32 = []
results33 = []
results34 = []
results35 = []
results36 = []
results37 = []
results38 = []
results39 = []
results40 = []
results41 = []
results42 = []
results43 = []
results44 = []
results45 = []
results46 = []
results47 = []
results48 = []
results49 = []

# Pulling all the average temps per day from each city
for x in x:
        results0.append(jul_data[0]["data"]["weather"][x]["avgtempF"])
        results1.append(jul_data[1]["data"]["weather"][x]["avgtempF"])
        results2.append(jul_data[2]["data"]["weather"][x]["avgtempF"])
        results3.append(jul_data[3]["data"]["weather"][x]["avgtempF"])
        results4.append(jul_data[4]["data"]["weather"][x]["avgtempF"])
        results5.append(jul_data[5]["data"]["weather"][x]["avgtempF"])
        results6.append(jul_data[6]["data"]["weather"][x]["avgtempF"])
        results7.append(jul_data[7]["data"]["weather"][x]["avgtempF"])
        results8.append(jul_data[8]["data"]["weather"][x]["avgtempF"])
        results9.append(jul_data[9]["data"]["weather"][x]["avgtempF"])
        results10.append(jul_data[10]["data"]["weather"][x]["avgtempF"])
        results11.append(jul_data[11]["data"]["weather"][x]["avgtempF"])
        results12.append(jul_data[12]["data"]["weather"][x]["avgtempF"])
        results13.append(jul_data[13]["data"]["weather"][x]["avgtempF"])
        results14.append(jul_data[14]["data"]["weather"][x]["avgtempF"])
        results15.append(jul_data[15]["data"]["weather"][x]["avgtempF"])
        results16.append(jul_data[16]["data"]["weather"][x]["avgtempF"])
        results17.append(jul_data[17]["data"]["weather"][x]["avgtempF"])
        results18.append(jul_data[18]["data"]["weather"][x]["avgtempF"])
        results19.append(jul_data[19]["data"]["weather"][x]["avgtempF"])
        results20.append(jul_data[20]["data"]["weather"][x]["avgtempF"])
        results21.append(jul_data[21]["data"]["weather"][x]["avgtempF"])
        results22.append(jul_data[22]["data"]["weather"][x]["avgtempF"])
        results23.append(jul_data[23]["data"]["weather"][x]["avgtempF"])
        results24.append(jul_data[24]["data"]["weather"][x]["avgtempF"])
        results25.append(jul_data[25]["data"]["weather"][x]["avgtempF"])
        results26.append(jul_data[26]["data"]["weather"][x]["avgtempF"])
        results27.append(jul_data[27]["data"]["weather"][x]["avgtempF"])
        results28.append(jul_data[28]["data"]["weather"][x]["avgtempF"])
        results29.append(jul_data[29]["data"]["weather"][x]["avgtempF"])
        results30.append(jul_data[30]["data"]["weather"][x]["avgtempF"])
        results31.append(jul_data[31]["data"]["weather"][x]["avgtempF"])
        results32.append(jul_data[32]["data"]["weather"][x]["avgtempF"])
        results33.append(jul_data[33]["data"]["weather"][x]["avgtempF"])
        results34.append(jul_data[34]["data"]["weather"][x]["avgtempF"])
        results35.append(jul_data[35]["data"]["weather"][x]["avgtempF"])
        results36.append(jul_data[36]["data"]["weather"][x]["avgtempF"])
        results37.append(jul_data[37]["data"]["weather"][x]["avgtempF"])
        results38.append(jul_data[38]["data"]["weather"][x]["avgtempF"])
        results39.append(jul_data[39]["data"]["weather"][x]["avgtempF"])
        results40.append(jul_data[40]["data"]["weather"][x]["avgtempF"])
        results41.append(jul_data[41]["data"]["weather"][x]["avgtempF"])
        results42.append(jul_data[42]["data"]["weather"][x]["avgtempF"])
        results43.append(jul_data[43]["data"]["weather"][x]["avgtempF"])
        results44.append(jul_data[44]["data"]["weather"][x]["avgtempF"])
        results45.append(jul_data[45]["data"]["weather"][x]["avgtempF"])
        results46.append(jul_data[46]["data"]["weather"][x]["avgtempF"])
        results47.append(jul_data[47]["data"]["weather"][x]["avgtempF"])
        results48.append(jul_data[48]["data"]["weather"][x]["avgtempF"])
        results49.append(jul_data[49]["data"]["weather"][x]["avgtempF"])

# %%
# Putting all the data into the df
weather_df7.loc["New York","July"] = results0
weather_df7.loc["Los Angeles","July"] = results1
weather_df7.loc["Chicago","July"] = results2
weather_df7.loc["Houston","July"] = results3
weather_df7.loc["Phoenix","July"] = results4
weather_df7.loc["Philadelphia","July"] = results5
weather_df7.loc["San Antonio","July"] = results6
weather_df7.loc["San Diego","July"] = results7
weather_df7.loc["Dallas","July"] = results8
weather_df7.loc["San Jose","July"] = results9

weather_df7.loc["Austin","July"] = results10
weather_df7.loc["Jacksonville","July"] = results11
weather_df7.loc["Fort Worth","July"] = results12
weather_df7.loc["Columbus","July"] = results13
weather_df7.loc["Charlotte","July"] = results14
weather_df7.loc["San Francisco","July"] = results15
weather_df7.loc["Indianapolis","July"] = results16
weather_df7.loc["Seattle","July"] = results17
weather_df7.loc["Denver","July"] = results18
weather_df7.loc["Washington","July"] = results19

weather_df7.loc["Boston","July"] = results20
weather_df7.loc["El Paso","July"] = results21
weather_df7.loc["Nashville","July"] = results22
weather_df7.loc["Detroit","July"] = results23
weather_df7.loc["Oklahoma City","July"] = results24
weather_df7.loc["Portland","July"] = results25
weather_df7.loc["Las Vegas","July"] = results26
weather_df7.loc["Memphis","July"] = results27
weather_df7.loc["Louisville","July"] = results28
weather_df7.loc["Baltimore","July"] = results29

weather_df7.loc["Milwaukee","July"] = results30
weather_df7.loc["Albuquerque","July"] = results31
weather_df7.loc["Tucson","July"] = results32
weather_df7.loc["Fresno","July"] = results33
weather_df7.loc["Mesa","July"] = results34
weather_df7.loc["Sacramento","July"] = results35
weather_df7.loc["Atlanta","July"] = results36
weather_df7.loc["Kansas City","July"] = results37
weather_df7.loc["Colorado Springs","July"] = results38
weather_df7.loc["Omaha","July"] = results39

weather_df7.loc["Raleigh","July"] = results40
weather_df7.loc["Miami","July"] = results41
weather_df7.loc["Long Beach","July"] = results42
weather_df7.loc["Virginia Beach","July"] = results43
weather_df7.loc["Oakland","July"] = results44
weather_df7.loc["Minneapolis","July"] = results45
weather_df7.loc["Tulsa","July"] = results46
weather_df7.loc["Tampa","July"] = results47
weather_df7.loc["Arlington","July"] = results48
weather_df7.loc["New Orleans","July"] = results49

# %%
# results for August and each of the top 50 states
x = np.arange(0, 31, 1)
results0 = []
results1 = []
results2 = []
results3 = []
results4 = []
results5 = []
results6 = []
results7 = []
results8 = []
results9 = []
results10 = []
results11 = []
results12 = []
results13 = []
results14 = []
results15 = []
results16 = []
results17 = []
results18 = []
results19 = []
results20 = []
results21 = []
results22 = []
results23 = []
results24 = []
results25 = []
results26 = []
results27 = []
results28 = []
results29 = []
results30 = []
results31 = []
results32 = []
results33 = []
results34 = []
results35 = []
results36 = []
results37 = []
results38 = []
results39 = []
results40 = []
results41 = []
results42 = []
results43 = []
results44 = []
results45 = []
results46 = []
results47 = []
results48 = []
results49 = []

# Pulling all the average temps per day from each city
for x in x:
        results0.append(aug_data[0]["data"]["weather"][x]["avgtempF"])
        results1.append(aug_data[1]["data"]["weather"][x]["avgtempF"])
        results2.append(aug_data[2]["data"]["weather"][x]["avgtempF"])
        results3.append(aug_data[3]["data"]["weather"][x]["avgtempF"])
        results4.append(aug_data[4]["data"]["weather"][x]["avgtempF"])
        results5.append(aug_data[5]["data"]["weather"][x]["avgtempF"])
        results6.append(aug_data[6]["data"]["weather"][x]["avgtempF"])
        results7.append(aug_data[7]["data"]["weather"][x]["avgtempF"])
        results8.append(aug_data[8]["data"]["weather"][x]["avgtempF"])
        results9.append(aug_data[9]["data"]["weather"][x]["avgtempF"])
        results10.append(aug_data[10]["data"]["weather"][x]["avgtempF"])
        results11.append(aug_data[11]["data"]["weather"][x]["avgtempF"])
        results12.append(aug_data[12]["data"]["weather"][x]["avgtempF"])
        results13.append(aug_data[13]["data"]["weather"][x]["avgtempF"])
        results14.append(aug_data[14]["data"]["weather"][x]["avgtempF"])
        results15.append(aug_data[15]["data"]["weather"][x]["avgtempF"])
        results16.append(aug_data[16]["data"]["weather"][x]["avgtempF"])
        results17.append(aug_data[17]["data"]["weather"][x]["avgtempF"])
        results18.append(aug_data[18]["data"]["weather"][x]["avgtempF"])
        results19.append(aug_data[19]["data"]["weather"][x]["avgtempF"])
        results20.append(aug_data[20]["data"]["weather"][x]["avgtempF"])
        results21.append(aug_data[21]["data"]["weather"][x]["avgtempF"])
        results22.append(aug_data[22]["data"]["weather"][x]["avgtempF"])
        results23.append(aug_data[23]["data"]["weather"][x]["avgtempF"])
        results24.append(aug_data[24]["data"]["weather"][x]["avgtempF"])
        results25.append(aug_data[25]["data"]["weather"][x]["avgtempF"])
        results26.append(aug_data[26]["data"]["weather"][x]["avgtempF"])
        results27.append(aug_data[27]["data"]["weather"][x]["avgtempF"])
        results28.append(aug_data[28]["data"]["weather"][x]["avgtempF"])
        results29.append(aug_data[29]["data"]["weather"][x]["avgtempF"])
        results30.append(aug_data[30]["data"]["weather"][x]["avgtempF"])
        results31.append(aug_data[31]["data"]["weather"][x]["avgtempF"])
        results32.append(aug_data[32]["data"]["weather"][x]["avgtempF"])
        results33.append(aug_data[33]["data"]["weather"][x]["avgtempF"])
        results34.append(aug_data[34]["data"]["weather"][x]["avgtempF"])
        results35.append(aug_data[35]["data"]["weather"][x]["avgtempF"])
        results36.append(aug_data[36]["data"]["weather"][x]["avgtempF"])
        results37.append(aug_data[37]["data"]["weather"][x]["avgtempF"])
        results38.append(aug_data[38]["data"]["weather"][x]["avgtempF"])
        results39.append(aug_data[39]["data"]["weather"][x]["avgtempF"])
        results40.append(aug_data[40]["data"]["weather"][x]["avgtempF"])
        results41.append(aug_data[41]["data"]["weather"][x]["avgtempF"])
        results42.append(aug_data[42]["data"]["weather"][x]["avgtempF"])
        results43.append(aug_data[43]["data"]["weather"][x]["avgtempF"])
        results44.append(aug_data[44]["data"]["weather"][x]["avgtempF"])
        results45.append(aug_data[45]["data"]["weather"][x]["avgtempF"])
        results46.append(aug_data[46]["data"]["weather"][x]["avgtempF"])
        results47.append(aug_data[47]["data"]["weather"][x]["avgtempF"])
        results48.append(aug_data[48]["data"]["weather"][x]["avgtempF"])
        results49.append(aug_data[49]["data"]["weather"][x]["avgtempF"])

# %%
# Putting all the data into the df
weather_df8.loc["New York","August"] = results0
weather_df8.loc["Los Angeles","August"] = results1
weather_df8.loc["Chicago","August"] = results2
weather_df8.loc["Houston","August"] = results3
weather_df8.loc["Phoenix","August"] = results4
weather_df8.loc["Philadelphia","August"] = results5
weather_df8.loc["San Antonio","August"] = results6
weather_df8.loc["San Diego","August"] = results7
weather_df8.loc["Dallas","August"] = results8
weather_df8.loc["San Jose","August"] = results9

weather_df8.loc["Austin","August"] = results10
weather_df8.loc["Jacksonville","August"] = results11
weather_df8.loc["Fort Worth","August"] = results12
weather_df8.loc["Columbus","August"] = results13
weather_df8.loc["Charlotte","August"] = results14
weather_df8.loc["San Francisco","August"] = results15
weather_df8.loc["Indianapolis","August"] = results16
weather_df8.loc["Seattle","August"] = results17
weather_df8.loc["Denver","August"] = results18
weather_df8.loc["Washington","August"] = results19

weather_df8.loc["Boston","August"] = results20
weather_df8.loc["El Paso","August"] = results21
weather_df8.loc["Nashville","August"] = results22
weather_df8.loc["Detroit","August"] = results23
weather_df8.loc["Oklahoma City","August"] = results24
weather_df8.loc["Portland","August"] = results25
weather_df8.loc["Las Vegas","August"] = results26
weather_df8.loc["Memphis","August"] = results27
weather_df8.loc["Louisville","August"] = results28
weather_df8.loc["Baltimore","August"] = results29

weather_df8.loc["Milwaukee","August"] = results30
weather_df8.loc["Albuquerque","August"] = results31
weather_df8.loc["Tucson","August"] = results32
weather_df8.loc["Fresno","August"] = results33
weather_df8.loc["Mesa","August"] = results34
weather_df8.loc["Sacramento","August"] = results35
weather_df8.loc["Atlanta","August"] = results36
weather_df8.loc["Kansas City","August"] = results37
weather_df8.loc["Colorado Springs","August"] = results38
weather_df8.loc["Omaha","August"] = results39

weather_df8.loc["Raleigh","August"] = results40
weather_df8.loc["Miami","August"] = results41
weather_df8.loc["Long Beach","August"] = results42
weather_df8.loc["Virginia Beach","August"] = results43
weather_df8.loc["Oakland","August"] = results44
weather_df8.loc["Minneapolis","August"] = results45
weather_df8.loc["Tulsa","August"] = results46
weather_df8.loc["Tampa","August"] = results47
weather_df8.loc["Arlington","August"] = results48
weather_df8.loc["New Orleans","August"] = results49

# %%
# results for September and each of the top 50 states
x = np.arange(0, 30, 1)
results0 = []
results1 = []
results2 = []
results3 = []
results4 = []
results5 = []
results6 = []
results7 = []
results8 = []
results9 = []
results10 = []
results11 = []
results12 = []
results13 = []
results14 = []
results15 = []
results16 = []
results17 = []
results18 = []
results19 = []
results20 = []
results21 = []
results22 = []
results23 = []
results24 = []
results25 = []
results26 = []
results27 = []
results28 = []
results29 = []
results30 = []
results31 = []
results32 = []
results33 = []
results34 = []
results35 = []
results36 = []
results37 = []
results38 = []
results39 = []
results40 = []
results41 = []
results42 = []
results43 = []
results44 = []
results45 = []
results46 = []
results47 = []
results48 = []
results49 = []

# Pulling all the average temps per day from each city
for x in x:
        results0.append(sep_data[0]["data"]["weather"][x]["avgtempF"])
        results1.append(sep_data[1]["data"]["weather"][x]["avgtempF"])
        results2.append(sep_data[2]["data"]["weather"][x]["avgtempF"])
        results3.append(sep_data[3]["data"]["weather"][x]["avgtempF"])
        results4.append(sep_data[4]["data"]["weather"][x]["avgtempF"])
        results5.append(sep_data[5]["data"]["weather"][x]["avgtempF"])
        results6.append(sep_data[6]["data"]["weather"][x]["avgtempF"])
        results7.append(sep_data[7]["data"]["weather"][x]["avgtempF"])
        results8.append(sep_data[8]["data"]["weather"][x]["avgtempF"])
        results9.append(sep_data[9]["data"]["weather"][x]["avgtempF"])
        results10.append(sep_data[10]["data"]["weather"][x]["avgtempF"])
        results11.append(sep_data[11]["data"]["weather"][x]["avgtempF"])
        results12.append(sep_data[12]["data"]["weather"][x]["avgtempF"])
        results13.append(sep_data[13]["data"]["weather"][x]["avgtempF"])
        results14.append(sep_data[14]["data"]["weather"][x]["avgtempF"])
        results15.append(sep_data[15]["data"]["weather"][x]["avgtempF"])
        results16.append(sep_data[16]["data"]["weather"][x]["avgtempF"])
        results17.append(sep_data[17]["data"]["weather"][x]["avgtempF"])
        results18.append(sep_data[18]["data"]["weather"][x]["avgtempF"])
        results19.append(sep_data[19]["data"]["weather"][x]["avgtempF"])
        results20.append(sep_data[20]["data"]["weather"][x]["avgtempF"])
        results21.append(sep_data[21]["data"]["weather"][x]["avgtempF"])
        results22.append(sep_data[22]["data"]["weather"][x]["avgtempF"])
        results23.append(sep_data[23]["data"]["weather"][x]["avgtempF"])
        results24.append(sep_data[24]["data"]["weather"][x]["avgtempF"])
        results25.append(sep_data[25]["data"]["weather"][x]["avgtempF"])
        results26.append(sep_data[26]["data"]["weather"][x]["avgtempF"])
        results27.append(sep_data[27]["data"]["weather"][x]["avgtempF"])
        results28.append(sep_data[28]["data"]["weather"][x]["avgtempF"])
        results29.append(sep_data[29]["data"]["weather"][x]["avgtempF"])
        results30.append(sep_data[30]["data"]["weather"][x]["avgtempF"])
        results31.append(sep_data[31]["data"]["weather"][x]["avgtempF"])
        results32.append(sep_data[32]["data"]["weather"][x]["avgtempF"])
        results33.append(sep_data[33]["data"]["weather"][x]["avgtempF"])
        results34.append(sep_data[34]["data"]["weather"][x]["avgtempF"])
        results35.append(sep_data[35]["data"]["weather"][x]["avgtempF"])
        results36.append(sep_data[36]["data"]["weather"][x]["avgtempF"])
        results37.append(sep_data[37]["data"]["weather"][x]["avgtempF"])
        results38.append(sep_data[38]["data"]["weather"][x]["avgtempF"])
        results39.append(sep_data[39]["data"]["weather"][x]["avgtempF"])
        results40.append(sep_data[40]["data"]["weather"][x]["avgtempF"])
        results41.append(sep_data[41]["data"]["weather"][x]["avgtempF"])
        results42.append(sep_data[42]["data"]["weather"][x]["avgtempF"])
        results43.append(sep_data[43]["data"]["weather"][x]["avgtempF"])
        results44.append(sep_data[44]["data"]["weather"][x]["avgtempF"])
        results45.append(sep_data[45]["data"]["weather"][x]["avgtempF"])
        results46.append(sep_data[46]["data"]["weather"][x]["avgtempF"])
        results47.append(sep_data[47]["data"]["weather"][x]["avgtempF"])
        results48.append(sep_data[48]["data"]["weather"][x]["avgtempF"])
        results49.append(sep_data[49]["data"]["weather"][x]["avgtempF"])

# %%
# Putting all the data into the df
weather_df9.loc["New York","September"] = results0
weather_df9.loc["Los Angeles","September"] = results1
weather_df9.loc["Chicago","September"] = results2
weather_df9.loc["Houston","September"] = results3
weather_df9.loc["Phoenix","September"] = results4
weather_df9.loc["Philadelphia","September"] = results5
weather_df9.loc["San Antonio","September"] = results6
weather_df9.loc["San Diego","September"] = results7
weather_df9.loc["Dallas","September"] = results8
weather_df9.loc["San Jose","September"] = results9

weather_df9.loc["Austin","September"] = results10
weather_df9.loc["Jacksonville","September"] = results11
weather_df9.loc["Fort Worth","September"] = results12
weather_df9.loc["Columbus","September"] = results13
weather_df9.loc["Charlotte","September"] = results14
weather_df9.loc["San Francisco","September"] = results15
weather_df9.loc["Indianapolis","September"] = results16
weather_df9.loc["Seattle","September"] = results17
weather_df9.loc["Denver","September"] = results18
weather_df9.loc["Washington","September"] = results19

weather_df9.loc["Boston","September"] = results20
weather_df9.loc["El Paso","September"] = results21
weather_df9.loc["Nashville","September"] = results22
weather_df9.loc["Detroit","September"] = results23
weather_df9.loc["Oklahoma City","September"] = results24
weather_df9.loc["Portland","September"] = results25
weather_df9.loc["Las Vegas","September"] = results26
weather_df9.loc["Memphis","September"] = results27
weather_df9.loc["Louisville","September"] = results28
weather_df9.loc["Baltimore","September"] = results29

weather_df9.loc["Milwaukee","September"] = results30
weather_df9.loc["Albuquerque","September"] = results31
weather_df9.loc["Tucson","September"] = results32
weather_df9.loc["Fresno","September"] = results33
weather_df9.loc["Mesa","September"] = results34
weather_df9.loc["Sacramento","September"] = results35
weather_df9.loc["Atlanta","September"] = results36
weather_df9.loc["Kansas City","September"] = results37
weather_df9.loc["Colorado Springs","September"] = results38
weather_df9.loc["Omaha","September"] = results39

weather_df9.loc["Raleigh","September"] = results40
weather_df9.loc["Miami","September"] = results41
weather_df9.loc["Long Beach","September"] = results42
weather_df9.loc["Virginia Beach","September"] = results43
weather_df9.loc["Oakland","September"] = results44
weather_df9.loc["Minneapolis","September"] = results45
weather_df9.loc["Tulsa","September"] = results46
weather_df9.loc["Tampa","September"] = results47
weather_df9.loc["Arlington","September"] = results48
weather_df9.loc["New Orleans","September"] = results49

# %%
# results for October and each of the top 50 states
x = np.arange(0, 31, 1)
results0 = []
results1 = []
results2 = []
results3 = []
results4 = []
results5 = []
results6 = []
results7 = []
results8 = []
results9 = []
results10 = []
results11 = []
results12 = []
results13 = []
results14 = []
results15 = []
results16 = []
results17 = []
results18 = []
results19 = []
results20 = []
results21 = []
results22 = []
results23 = []
results24 = []
results25 = []
results26 = []
results27 = []
results28 = []
results29 = []
results30 = []
results31 = []
results32 = []
results33 = []
results34 = []
results35 = []
results36 = []
results37 = []
results38 = []
results39 = []
results40 = []
results41 = []
results42 = []
results43 = []
results44 = []
results45 = []
results46 = []
results47 = []
results48 = []
results49 = []

# Pulling all the average temps per day from each city
for x in x:
        results0.append(oct_data[0]["data"]["weather"][x]["avgtempF"])
        results1.append(oct_data[1]["data"]["weather"][x]["avgtempF"])
        results2.append(oct_data[2]["data"]["weather"][x]["avgtempF"])
        results3.append(oct_data[3]["data"]["weather"][x]["avgtempF"])
        results4.append(oct_data[4]["data"]["weather"][x]["avgtempF"])
        results5.append(oct_data[5]["data"]["weather"][x]["avgtempF"])
        results6.append(oct_data[6]["data"]["weather"][x]["avgtempF"])
        results7.append(oct_data[7]["data"]["weather"][x]["avgtempF"])
        results8.append(oct_data[8]["data"]["weather"][x]["avgtempF"])
        results9.append(oct_data[9]["data"]["weather"][x]["avgtempF"])
        results10.append(oct_data[10]["data"]["weather"][x]["avgtempF"])
        results11.append(oct_data[11]["data"]["weather"][x]["avgtempF"])
        results12.append(oct_data[12]["data"]["weather"][x]["avgtempF"])
        results13.append(oct_data[13]["data"]["weather"][x]["avgtempF"])
        results14.append(oct_data[14]["data"]["weather"][x]["avgtempF"])
        results15.append(oct_data[15]["data"]["weather"][x]["avgtempF"])
        results16.append(oct_data[16]["data"]["weather"][x]["avgtempF"])
        results17.append(oct_data[17]["data"]["weather"][x]["avgtempF"])
        results18.append(oct_data[18]["data"]["weather"][x]["avgtempF"])
        results19.append(oct_data[19]["data"]["weather"][x]["avgtempF"])
        results20.append(oct_data[20]["data"]["weather"][x]["avgtempF"])
        results21.append(oct_data[21]["data"]["weather"][x]["avgtempF"])
        results22.append(oct_data[22]["data"]["weather"][x]["avgtempF"])
        results23.append(oct_data[23]["data"]["weather"][x]["avgtempF"])
        results24.append(oct_data[24]["data"]["weather"][x]["avgtempF"])
        results25.append(oct_data[25]["data"]["weather"][x]["avgtempF"])
        results26.append(oct_data[26]["data"]["weather"][x]["avgtempF"])
        results27.append(oct_data[27]["data"]["weather"][x]["avgtempF"])
        results28.append(oct_data[28]["data"]["weather"][x]["avgtempF"])
        results29.append(oct_data[29]["data"]["weather"][x]["avgtempF"])
        results30.append(oct_data[30]["data"]["weather"][x]["avgtempF"])
        results31.append(oct_data[31]["data"]["weather"][x]["avgtempF"])
        results32.append(oct_data[32]["data"]["weather"][x]["avgtempF"])
        results33.append(oct_data[33]["data"]["weather"][x]["avgtempF"])
        results34.append(oct_data[34]["data"]["weather"][x]["avgtempF"])
        results35.append(oct_data[35]["data"]["weather"][x]["avgtempF"])
        results36.append(oct_data[36]["data"]["weather"][x]["avgtempF"])
        results37.append(oct_data[37]["data"]["weather"][x]["avgtempF"])
        results38.append(oct_data[38]["data"]["weather"][x]["avgtempF"])
        results39.append(oct_data[39]["data"]["weather"][x]["avgtempF"])
        results40.append(oct_data[40]["data"]["weather"][x]["avgtempF"])
        results41.append(oct_data[41]["data"]["weather"][x]["avgtempF"])
        results42.append(oct_data[42]["data"]["weather"][x]["avgtempF"])
        results43.append(oct_data[43]["data"]["weather"][x]["avgtempF"])
        results44.append(oct_data[44]["data"]["weather"][x]["avgtempF"])
        results45.append(oct_data[45]["data"]["weather"][x]["avgtempF"])
        results46.append(oct_data[46]["data"]["weather"][x]["avgtempF"])
        results47.append(oct_data[47]["data"]["weather"][x]["avgtempF"])
        results48.append(oct_data[48]["data"]["weather"][x]["avgtempF"])
        results49.append(oct_data[49]["data"]["weather"][x]["avgtempF"])

# %%
# Putting all the data into the df
weather_df10.loc["New York","October"] = results0
weather_df10.loc["Los Angeles","October"] = results1
weather_df10.loc["Chicago","October"] = results2
weather_df10.loc["Houston","October"] = results3
weather_df10.loc["Phoenix","October"] = results4
weather_df10.loc["Philadelphia","October"] = results5
weather_df10.loc["San Antonio","October"] = results6
weather_df10.loc["San Diego","October"] = results7
weather_df10.loc["Dallas","October"] = results8
weather_df10.loc["San Jose","October"] = results9

weather_df10.loc["Austin","October"] = results10
weather_df10.loc["Jacksonville","October"] = results11
weather_df10.loc["Fort Worth","October"] = results12
weather_df10.loc["Columbus","October"] = results13
weather_df10.loc["Charlotte","October"] = results14
weather_df10.loc["San Francisco","October"] = results15
weather_df10.loc["Indianapolis","October"] = results16
weather_df10.loc["Seattle","October"] = results17
weather_df10.loc["Denver","October"] = results18
weather_df10.loc["Washington","October"] = results19

weather_df10.loc["Boston","October"] = results20
weather_df10.loc["El Paso","October"] = results21
weather_df10.loc["Nashville","October"] = results22
weather_df10.loc["Detroit","October"] = results23
weather_df10.loc["Oklahoma City","October"] = results24
weather_df10.loc["Portland","October"] = results25
weather_df10.loc["Las Vegas","October"] = results26
weather_df10.loc["Memphis","October"] = results27
weather_df10.loc["Louisville","October"] = results28
weather_df10.loc["Baltimore","October"] = results29

weather_df10.loc["Milwaukee","October"] = results30
weather_df10.loc["Albuquerque","October"] = results31
weather_df10.loc["Tucson","October"] = results32
weather_df10.loc["Fresno","October"] = results33
weather_df10.loc["Mesa","October"] = results34
weather_df10.loc["Sacramento","October"] = results35
weather_df10.loc["Atlanta","October"] = results36
weather_df10.loc["Kansas City","October"] = results37
weather_df10.loc["Colorado Springs","October"] = results38
weather_df10.loc["Omaha","October"] = results39

weather_df10.loc["Raleigh","October"] = results40
weather_df10.loc["Miami","October"] = results41
weather_df10.loc["Long Beach","October"] = results42
weather_df10.loc["Virginia Beach","October"] = results43
weather_df10.loc["Oakland","October"] = results44
weather_df10.loc["Minneapolis","October"] = results45
weather_df10.loc["Tulsa","October"] = results46
weather_df10.loc["Tampa","October"] = results47
weather_df10.loc["Arlington","October"] = results48
weather_df10.loc["New Orleans","October"] = results49

# %%
# results for November and each of the top 50 states
x = np.arange(0, 30, 1)
results0 = []
results1 = []
results2 = []
results3 = []
results4 = []
results5 = []
results6 = []
results7 = []
results8 = []
results9 = []
results10 = []
results11 = []
results12 = []
results13 = []
results14 = []
results15 = []
results16 = []
results17 = []
results18 = []
results19 = []
results20 = []
results21 = []
results22 = []
results23 = []
results24 = []
results25 = []
results26 = []
results27 = []
results28 = []
results29 = []
results30 = []
results31 = []
results32 = []
results33 = []
results34 = []
results35 = []
results36 = []
results37 = []
results38 = []
results39 = []
results40 = []
results41 = []
results42 = []
results43 = []
results44 = []
results45 = []
results46 = []
results47 = []
results48 = []
results49 = []

# Pulling all the average temps per day from each city
for x in x:
        results0.append(nov_data[0]["data"]["weather"][x]["avgtempF"])
        results1.append(nov_data[1]["data"]["weather"][x]["avgtempF"])
        results2.append(nov_data[2]["data"]["weather"][x]["avgtempF"])
        results3.append(nov_data[3]["data"]["weather"][x]["avgtempF"])
        results4.append(nov_data[4]["data"]["weather"][x]["avgtempF"])
        results5.append(nov_data[5]["data"]["weather"][x]["avgtempF"])
        results6.append(nov_data[6]["data"]["weather"][x]["avgtempF"])
        results7.append(nov_data[7]["data"]["weather"][x]["avgtempF"])
        results8.append(nov_data[8]["data"]["weather"][x]["avgtempF"])
        results9.append(nov_data[9]["data"]["weather"][x]["avgtempF"])
        results10.append(nov_data[10]["data"]["weather"][x]["avgtempF"])
        results11.append(nov_data[11]["data"]["weather"][x]["avgtempF"])
        results12.append(nov_data[12]["data"]["weather"][x]["avgtempF"])
        results13.append(nov_data[13]["data"]["weather"][x]["avgtempF"])
        results14.append(nov_data[14]["data"]["weather"][x]["avgtempF"])
        results15.append(nov_data[15]["data"]["weather"][x]["avgtempF"])
        results16.append(nov_data[16]["data"]["weather"][x]["avgtempF"])
        results17.append(nov_data[17]["data"]["weather"][x]["avgtempF"])
        results18.append(nov_data[18]["data"]["weather"][x]["avgtempF"])
        results19.append(nov_data[19]["data"]["weather"][x]["avgtempF"])
        results20.append(nov_data[20]["data"]["weather"][x]["avgtempF"])
        results21.append(nov_data[21]["data"]["weather"][x]["avgtempF"])
        results22.append(nov_data[22]["data"]["weather"][x]["avgtempF"])
        results23.append(nov_data[23]["data"]["weather"][x]["avgtempF"])
        results24.append(nov_data[24]["data"]["weather"][x]["avgtempF"])
        results25.append(nov_data[25]["data"]["weather"][x]["avgtempF"])
        results26.append(nov_data[26]["data"]["weather"][x]["avgtempF"])
        results27.append(nov_data[27]["data"]["weather"][x]["avgtempF"])
        results28.append(nov_data[28]["data"]["weather"][x]["avgtempF"])
        results29.append(nov_data[29]["data"]["weather"][x]["avgtempF"])
        results30.append(nov_data[30]["data"]["weather"][x]["avgtempF"])
        results31.append(nov_data[31]["data"]["weather"][x]["avgtempF"])
        results32.append(nov_data[32]["data"]["weather"][x]["avgtempF"])
        results33.append(nov_data[33]["data"]["weather"][x]["avgtempF"])
        results34.append(nov_data[34]["data"]["weather"][x]["avgtempF"])
        results35.append(nov_data[35]["data"]["weather"][x]["avgtempF"])
        results36.append(nov_data[36]["data"]["weather"][x]["avgtempF"])
        results37.append(nov_data[37]["data"]["weather"][x]["avgtempF"])
        results38.append(nov_data[38]["data"]["weather"][x]["avgtempF"])
        results39.append(nov_data[39]["data"]["weather"][x]["avgtempF"])
        results40.append(nov_data[40]["data"]["weather"][x]["avgtempF"])
        results41.append(nov_data[41]["data"]["weather"][x]["avgtempF"])
        results42.append(nov_data[42]["data"]["weather"][x]["avgtempF"])
        results43.append(nov_data[43]["data"]["weather"][x]["avgtempF"])
        results44.append(nov_data[44]["data"]["weather"][x]["avgtempF"])
        results45.append(nov_data[45]["data"]["weather"][x]["avgtempF"])
        results46.append(nov_data[46]["data"]["weather"][x]["avgtempF"])
        results47.append(nov_data[47]["data"]["weather"][x]["avgtempF"])
        results48.append(nov_data[48]["data"]["weather"][x]["avgtempF"])
        results49.append(nov_data[49]["data"]["weather"][x]["avgtempF"])

# %%
# Putting all the data into the df
weather_df11.loc["New York","November"] = results0
weather_df11.loc["Los Angeles","November"] = results1
weather_df11.loc["Chicago","November"] = results2
weather_df11.loc["Houston","November"] = results3
weather_df11.loc["Phoenix","November"] = results4
weather_df11.loc["Philadelphia","November"] = results5
weather_df11.loc["San Antonio","November"] = results6
weather_df11.loc["San Diego","November"] = results7
weather_df11.loc["Dallas","November"] = results8
weather_df11.loc["San Jose","November"] = results9

weather_df11.loc["Austin","November"] = results10
weather_df11.loc["Jacksonville","November"] = results11
weather_df11.loc["Fort Worth","November"] = results12
weather_df11.loc["Columbus","November"] = results13
weather_df11.loc["Charlotte","November"] = results14
weather_df11.loc["San Francisco","November"] = results15
weather_df11.loc["Indianapolis","November"] = results16
weather_df11.loc["Seattle","November"] = results17
weather_df11.loc["Denver","November"] = results18
weather_df11.loc["Washington","November"] = results19

weather_df11.loc["Boston","November"] = results20
weather_df11.loc["El Paso","November"] = results21
weather_df11.loc["Nashville","November"] = results22
weather_df11.loc["Detroit","November"] = results23
weather_df11.loc["Oklahoma City","November"] = results24
weather_df11.loc["Portland","November"] = results25
weather_df11.loc["Las Vegas","November"] = results26
weather_df11.loc["Memphis","November"] = results27
weather_df11.loc["Louisville","November"] = results28
weather_df11.loc["Baltimore","November"] = results29

weather_df11.loc["Milwaukee","November"] = results30
weather_df11.loc["Albuquerque","November"] = results31
weather_df11.loc["Tucson","November"] = results32
weather_df11.loc["Fresno","November"] = results33
weather_df11.loc["Mesa","November"] = results34
weather_df11.loc["Sacramento","November"] = results35
weather_df11.loc["Atlanta","November"] = results36
weather_df11.loc["Kansas City","November"] = results37
weather_df11.loc["Colorado Springs","November"] = results38
weather_df11.loc["Omaha","November"] = results39

weather_df11.loc["Raleigh","November"] = results40
weather_df11.loc["Miami","November"] = results41
weather_df11.loc["Long Beach","November"] = results42
weather_df11.loc["Virginia Beach","November"] = results43
weather_df11.loc["Oakland","November"] = results44
weather_df11.loc["Minneapolis","November"] = results45
weather_df11.loc["Tulsa","November"] = results46
weather_df11.loc["Tampa","November"] = results47
weather_df11.loc["Arlington","November"] = results48
weather_df11.loc["New Orleans","November"] = results49

# %%
# results for December and each of the top 50 states
x = np.arange(0, 31, 1)
results0 = []
results1 = []
results2 = []
results3 = []
results4 = []
results5 = []
results6 = []
results7 = []
results8 = []
results9 = []
results10 = []
results11 = []
results12 = []
results13 = []
results14 = []
results15 = []
results16 = []
results17 = []
results18 = []
results19 = []
results20 = []
results21 = []
results22 = []
results23 = []
results24 = []
results25 = []
results26 = []
results27 = []
results28 = []
results29 = []
results30 = []
results31 = []
results32 = []
results33 = []
results34 = []
results35 = []
results36 = []
results37 = []
results38 = []
results39 = []
results40 = []
results41 = []
results42 = []
results43 = []
results44 = []
results45 = []
results46 = []
results47 = []
results48 = []
results49 = []

# Pulling all the average temps per day from each city
for x in x:
        results0.append(dec_data[0]["data"]["weather"][x]["avgtempF"])
        results1.append(dec_data[1]["data"]["weather"][x]["avgtempF"])
        results2.append(dec_data[2]["data"]["weather"][x]["avgtempF"])
        results3.append(dec_data[3]["data"]["weather"][x]["avgtempF"])
        results4.append(dec_data[4]["data"]["weather"][x]["avgtempF"])
        results5.append(dec_data[5]["data"]["weather"][x]["avgtempF"])
        results6.append(dec_data[6]["data"]["weather"][x]["avgtempF"])
        results7.append(dec_data[7]["data"]["weather"][x]["avgtempF"])
        results8.append(dec_data[8]["data"]["weather"][x]["avgtempF"])
        results9.append(dec_data[9]["data"]["weather"][x]["avgtempF"])
        results10.append(dec_data[10]["data"]["weather"][x]["avgtempF"])
        results11.append(dec_data[11]["data"]["weather"][x]["avgtempF"])
        results12.append(dec_data[12]["data"]["weather"][x]["avgtempF"])
        results13.append(dec_data[13]["data"]["weather"][x]["avgtempF"])
        results14.append(dec_data[14]["data"]["weather"][x]["avgtempF"])
        results15.append(dec_data[15]["data"]["weather"][x]["avgtempF"])
        results16.append(dec_data[16]["data"]["weather"][x]["avgtempF"])
        results17.append(dec_data[17]["data"]["weather"][x]["avgtempF"])
        results18.append(dec_data[18]["data"]["weather"][x]["avgtempF"])
        results19.append(dec_data[19]["data"]["weather"][x]["avgtempF"])
        results20.append(dec_data[20]["data"]["weather"][x]["avgtempF"])
        results21.append(dec_data[21]["data"]["weather"][x]["avgtempF"])
        results22.append(dec_data[22]["data"]["weather"][x]["avgtempF"])
        results23.append(dec_data[23]["data"]["weather"][x]["avgtempF"])
        results24.append(dec_data[24]["data"]["weather"][x]["avgtempF"])
        results25.append(dec_data[25]["data"]["weather"][x]["avgtempF"])
        results26.append(dec_data[26]["data"]["weather"][x]["avgtempF"])
        results27.append(dec_data[27]["data"]["weather"][x]["avgtempF"])
        results28.append(dec_data[28]["data"]["weather"][x]["avgtempF"])
        results29.append(dec_data[29]["data"]["weather"][x]["avgtempF"])
        results30.append(dec_data[30]["data"]["weather"][x]["avgtempF"])
        results31.append(dec_data[31]["data"]["weather"][x]["avgtempF"])
        results32.append(dec_data[32]["data"]["weather"][x]["avgtempF"])
        results33.append(dec_data[33]["data"]["weather"][x]["avgtempF"])
        results34.append(dec_data[34]["data"]["weather"][x]["avgtempF"])
        results35.append(dec_data[35]["data"]["weather"][x]["avgtempF"])
        results36.append(dec_data[36]["data"]["weather"][x]["avgtempF"])
        results37.append(dec_data[37]["data"]["weather"][x]["avgtempF"])
        results38.append(dec_data[38]["data"]["weather"][x]["avgtempF"])
        results39.append(dec_data[39]["data"]["weather"][x]["avgtempF"])
        results40.append(dec_data[40]["data"]["weather"][x]["avgtempF"])
        results41.append(dec_data[41]["data"]["weather"][x]["avgtempF"])
        results42.append(dec_data[42]["data"]["weather"][x]["avgtempF"])
        results43.append(dec_data[43]["data"]["weather"][x]["avgtempF"])
        results44.append(dec_data[44]["data"]["weather"][x]["avgtempF"])
        results45.append(dec_data[45]["data"]["weather"][x]["avgtempF"])
        results46.append(dec_data[46]["data"]["weather"][x]["avgtempF"])
        results47.append(dec_data[47]["data"]["weather"][x]["avgtempF"])
        results48.append(dec_data[48]["data"]["weather"][x]["avgtempF"])
        results49.append(dec_data[49]["data"]["weather"][x]["avgtempF"])

# %%
# Putting all the data into the df
weather_df12.loc["New York","December"] = results0
weather_df12.loc["Los Angeles","December"] = results1
weather_df12.loc["Chicago","December"] = results2
weather_df12.loc["Houston","December"] = results3
weather_df12.loc["Phoenix","December"] = results4
weather_df12.loc["Philadelphia","December"] = results5
weather_df12.loc["San Antonio","December"] = results6
weather_df12.loc["San Diego","December"] = results7
weather_df12.loc["Dallas","December"] = results8
weather_df12.loc["San Jose","December"] = results9

weather_df12.loc["Austin","December"] = results10
weather_df12.loc["Jacksonville","December"] = results11
weather_df12.loc["Fort Worth","December"] = results12
weather_df12.loc["Columbus","December"] = results13
weather_df12.loc["Charlotte","December"] = results14
weather_df12.loc["San Francisco","December"] = results15
weather_df12.loc["Indianapolis","December"] = results16
weather_df12.loc["Seattle","December"] = results17
weather_df12.loc["Denver","December"] = results18
weather_df12.loc["Washington","December"] = results19

weather_df12.loc["Boston","December"] = results20
weather_df12.loc["El Paso","December"] = results21
weather_df12.loc["Nashville","December"] = results22
weather_df12.loc["Detroit","December"] = results23
weather_df12.loc["Oklahoma City","December"] = results24
weather_df12.loc["Portland","December"] = results25
weather_df12.loc["Las Vegas","December"] = results26
weather_df12.loc["Memphis","December"] = results27
weather_df12.loc["Louisville","December"] = results28
weather_df12.loc["Baltimore","December"] = results29

weather_df12.loc["Milwaukee","December"] = results30
weather_df12.loc["Albuquerque","December"] = results31
weather_df12.loc["Tucson","December"] = results32
weather_df12.loc["Fresno","December"] = results33
weather_df12.loc["Mesa","December"] = results34
weather_df12.loc["Sacramento","December"] = results35
weather_df12.loc["Atlanta","December"] = results36
weather_df12.loc["Kansas City","December"] = results37
weather_df12.loc["Colorado Springs","December"] = results38
weather_df12.loc["Omaha","December"] = results39

weather_df12.loc["Raleigh","December"] = results40
weather_df12.loc["Miami","December"] = results41
weather_df12.loc["Long Beach","December"] = results42
weather_df12.loc["Virginia Beach","December"] = results43
weather_df12.loc["Oakland","December"] = results44
weather_df12.loc["Minneapolis","December"] = results45
weather_df12.loc["Tulsa","December"] = results46
weather_df12.loc["Tampa","December"] = results47
weather_df12.loc["Arlington","December"] = results48
weather_df12.loc["New Orleans","December"] = results49

# %%
weather_df1.to_csv(r'C:\Users\skm72\Desktop\Project Repo\Project-1\Stephen\Weather CSV\City Weather Q1.csv')

# %%
weather_df2.to_csv(r'C:\Users\skm72\Desktop\Project Repo\Project-1\Stephen\Weather CSV\City Weather Q2.csv')

# %%
weather_df3.to_csv(r'C:\Users\skm72\Desktop\Project Repo\Project-1\Stephen\Weather CSV\City Weather Q3.csv')

# %%
weather_df4.to_csv(r'C:\Users\skm72\Desktop\Project Repo\Project-1\Stephen\Weather CSV\City Weather Q4.csv')
